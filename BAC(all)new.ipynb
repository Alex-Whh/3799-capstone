# %%
import pandas as pd
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
df = pd.read_csv('BAC.csv')

df
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# 0      1973-02-21   4.625000   4.625000   4.625000   4.625000   1.640601
# 1      1973-02-22   4.640625   4.640625   4.640625   4.640625   1.646143
# 2      1973-02-23   4.625000   4.625000   4.625000   4.625000   1.640601
# 3      1973-02-26   4.625000   4.625000   4.625000   4.625000   1.640601
# 4      1973-02-27   4.625000   4.625000   4.625000   4.625000   1.640601
# ...           ...        ...        ...        ...        ...        ...
# 12548  2022-11-18  37.790001  37.849998  36.919998  37.189999  37.189999
# 12549  2022-11-21  37.090000  37.520000  37.060001  37.310001  37.310001
# 12550  2022-11-22  37.590000  37.799999  37.430000  37.490002  37.490002
# 12551  2022-11-23  37.490002  37.660000  37.369999  37.610001  37.610001
# 12552  2022-11-25  37.720001  37.869999  37.560001  37.700001  37.700001
#
#          Volume
# 0         99200
# 1         47200
# 2        133600
# 3         24000
# 4         41600
# ...         ...
# 12548  32038500
# 12549  27935700
# 12550  23499300
# 12551  18934700
# 12552  16118500
#
# [12553 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#              Date      Close
# 0      1973-02-21   4.625000
# 1      1973-02-22   4.640625
# 2      1973-02-23   4.625000
# 3      1973-02-26   4.625000
# 4      1973-02-27   4.625000
# ...           ...        ...
# 12548  2022-11-18  37.189999
# 12549  2022-11-21  37.310001
# 12550  2022-11-22  37.490002
# 12551  2022-11-23  37.610001
# 12552  2022-11-25  37.700001
#
# [12553 rows x 2 columns]

# %%
df['Date']
# Out:
# 0        1973-02-21
# 1        1973-02-22
# 2        1973-02-23
# 3        1973-02-26
# 4        1973-02-27
#             ...
# 12548    2022-11-18
# 12549    2022-11-21
# 12550    2022-11-22
# 12551    2022-11-23
# 12552    2022-11-25
# Name: Date, Length: 12553, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\Wu Honghao\AppData\Local\Temp\ipykernel_16908\2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0       1973-02-21
# 1       1973-02-22
# 2       1973-02-23
# 3       1973-02-26
# 4       1973-02-27
#            ...
# 12548   2022-11-18
# 12549   2022-11-21
# 12550   2022-11-22
# 12551   2022-11-23
# 12552   2022-11-25
# Name: Date, Length: 12553, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                 Close
# Date
# 1973-02-21   4.625000
# 1973-02-22   4.640625
# 1973-02-23   4.625000
# 1973-02-26   4.625000
# 1973-02-27   4.625000
# ...               ...
# 2022-11-18  37.189999
# 2022-11-21  37.310001
# 2022-11-22  37.490002
# 2022-11-23  37.610001
# 2022-11-25  37.700001
#
# [12553 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np
import random 
random.seed(1)

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '1974-01-20', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#       Target Date   Target-3   Target-2   Target-1     Target
# 0      1974-01-20   4.406250   4.562500   4.625000   4.562500
# 1      1974-01-22   4.625000   4.562500   4.437500   4.406250
# 2      1974-01-23   4.562500   4.437500   4.406250   4.312500
# 3      1974-01-24   4.437500   4.406250   4.312500   4.281250
# 4      1974-01-25   4.406250   4.312500   4.281250   4.328125
# ...           ...        ...        ...        ...        ...
# 12146  2022-03-17  41.200001  41.500000  42.799999  43.029999
# 12147  2022-03-18  41.500000  42.799999  43.029999  42.900002
# 12148  2022-03-21  42.799999  43.029999  42.900002  42.840000
# 12149  2022-03-22  43.029999  42.900002  42.840000  44.180000
# 12150  2022-03-23  42.900002  42.840000  44.180000  43.090000
#
# [12151 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((12151,), (12151, 3, 1), (12151,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 304/304 [==============================] - 3s 4ms/step - loss: 62.7088 - mean_absolute_error: 2.8866 - val_loss: 0.0751 - val_mean_absolute_error: 0.2067
# Epoch 2/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2627 - mean_absolute_error: 0.2835 - val_loss: 0.0796 - val_mean_absolute_error: 0.2130
# Epoch 3/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2606 - mean_absolute_error: 0.2854 - val_loss: 0.0841 - val_mean_absolute_error: 0.2172
# Epoch 4/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2526 - mean_absolute_error: 0.2757 - val_loss: 0.1253 - val_mean_absolute_error: 0.2803
# Epoch 5/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2629 - mean_absolute_error: 0.2864 - val_loss: 0.1043 - val_mean_absolute_error: 0.2566
# Epoch 6/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2437 - mean_absolute_error: 0.2729 - val_loss: 0.0718 - val_mean_absolute_error: 0.1991
# Epoch 7/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2692 - mean_absolute_error: 0.2898 - val_loss: 0.0847 - val_mean_absolute_error: 0.2216
# Epoch 8/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2560 - mean_absolute_error: 0.2826 - val_loss: 0.0781 - val_mean_absolute_error: 0.2111
# Epoch 9/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2475 - mean_absolute_error: 0.2767 - val_loss: 0.1645 - val_mean_absolute_error: 0.3437
# Epoch 10/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2520 - mean_absolute_error: 0.2815 - val_loss: 0.0764 - val_mean_absolute_error: 0.2069
# Epoch 11/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2562 - mean_absolute_error: 0.2804 - val_loss: 0.1035 - val_mean_absolute_error: 0.2481
# Epoch 12/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2386 - mean_absolute_error: 0.2689 - val_loss: 0.0813 - val_mean_absolute_error: 0.2180
# Epoch 13/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2592 - mean_absolute_error: 0.2863 - val_loss: 0.1243 - val_mean_absolute_error: 0.2827
# Epoch 14/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2570 - mean_absolute_error: 0.2832 - val_loss: 0.0668 - val_mean_absolute_error: 0.1911
# Epoch 15/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2543 - mean_absolute_error: 0.2832 - val_loss: 0.0671 - val_mean_absolute_error: 0.1916
# Epoch 16/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2398 - mean_absolute_error: 0.2729 - val_loss: 0.0661 - val_mean_absolute_error: 0.1896
# Epoch 17/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2396 - mean_absolute_error: 0.2709 - val_loss: 0.1557 - val_mean_absolute_error: 0.3288
# Epoch 18/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2704 - mean_absolute_error: 0.2918 - val_loss: 0.0698 - val_mean_absolute_error: 0.1972
# Epoch 19/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2493 - mean_absolute_error: 0.2815 - val_loss: 0.0653 - val_mean_absolute_error: 0.1875
# Epoch 20/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2597 - mean_absolute_error: 0.2891 - val_loss: 0.1559 - val_mean_absolute_error: 0.3330
# Epoch 21/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2426 - mean_absolute_error: 0.2761 - val_loss: 0.0773 - val_mean_absolute_error: 0.2094
# Epoch 22/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2417 - mean_absolute_error: 0.2710 - val_loss: 0.1065 - val_mean_absolute_error: 0.2590
# Epoch 23/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2463 - mean_absolute_error: 0.2738 - val_loss: 0.1046 - val_mean_absolute_error: 0.2543
# Epoch 24/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2612 - mean_absolute_error: 0.2872 - val_loss: 0.1208 - val_mean_absolute_error: 0.2785
# Epoch 25/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2520 - mean_absolute_error: 0.2835 - val_loss: 0.0676 - val_mean_absolute_error: 0.1932
# Epoch 26/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2435 - mean_absolute_error: 0.2719 - val_loss: 0.0652 - val_mean_absolute_error: 0.1878
# Epoch 27/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2294 - mean_absolute_error: 0.2590 - val_loss: 0.0797 - val_mean_absolute_error: 0.2125
# Epoch 28/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2427 - mean_absolute_error: 0.2776 - val_loss: 0.1150 - val_mean_absolute_error: 0.2697
# Epoch 29/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2595 - mean_absolute_error: 0.2878 - val_loss: 0.1197 - val_mean_absolute_error: 0.2798
# Epoch 30/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2494 - mean_absolute_error: 0.2792 - val_loss: 0.0777 - val_mean_absolute_error: 0.2100
# Epoch 31/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2554 - mean_absolute_error: 0.2875 - val_loss: 0.0931 - val_mean_absolute_error: 0.2354
# Epoch 32/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2523 - mean_absolute_error: 0.2815 - val_loss: 0.0931 - val_mean_absolute_error: 0.2408
# Epoch 33/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2618 - mean_absolute_error: 0.2895 - val_loss: 0.0745 - val_mean_absolute_error: 0.2066
# Epoch 34/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2613 - mean_absolute_error: 0.2822 - val_loss: 0.1123 - val_mean_absolute_error: 0.2681
# Epoch 35/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2504 - mean_absolute_error: 0.2787 - val_loss: 0.0984 - val_mean_absolute_error: 0.2463
# Epoch 36/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2502 - mean_absolute_error: 0.2830 - val_loss: 0.0941 - val_mean_absolute_error: 0.2387
# Epoch 37/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2490 - mean_absolute_error: 0.2774 - val_loss: 0.0678 - val_mean_absolute_error: 0.1916
# Epoch 38/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2434 - mean_absolute_error: 0.2737 - val_loss: 0.1400 - val_mean_absolute_error: 0.3065
# Epoch 39/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2469 - mean_absolute_error: 0.2812 - val_loss: 0.0826 - val_mean_absolute_error: 0.2222
# Epoch 40/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2468 - mean_absolute_error: 0.2771 - val_loss: 0.0765 - val_mean_absolute_error: 0.2082
# Epoch 41/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2459 - mean_absolute_error: 0.2787 - val_loss: 0.0879 - val_mean_absolute_error: 0.2336
# Epoch 42/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2547 - mean_absolute_error: 0.2836 - val_loss: 0.0821 - val_mean_absolute_error: 0.2202
# Epoch 43/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2400 - mean_absolute_error: 0.2715 - val_loss: 0.0771 - val_mean_absolute_error: 0.2099
# Epoch 44/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2358 - mean_absolute_error: 0.2677 - val_loss: 0.0652 - val_mean_absolute_error: 0.1869
# Epoch 45/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2366 - mean_absolute_error: 0.2724 - val_loss: 0.5016 - val_mean_absolute_error: 0.6587
# Epoch 46/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2586 - mean_absolute_error: 0.2838 - val_loss: 0.4549 - val_mean_absolute_error: 0.6211
# Epoch 47/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2518 - mean_absolute_error: 0.2816 - val_loss: 0.0790 - val_mean_absolute_error: 0.2106
# Epoch 48/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2481 - mean_absolute_error: 0.2770 - val_loss: 0.0669 - val_mean_absolute_error: 0.1909
# Epoch 49/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2367 - mean_absolute_error: 0.2664 - val_loss: 0.0654 - val_mean_absolute_error: 0.1883
# Epoch 50/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2644 - mean_absolute_error: 0.2887 - val_loss: 0.0705 - val_mean_absolute_error: 0.1981
# Epoch 51/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2241 - mean_absolute_error: 0.2598 - val_loss: 0.0972 - val_mean_absolute_error: 0.2425
# Epoch 52/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2396 - mean_absolute_error: 0.2696 - val_loss: 0.0923 - val_mean_absolute_error: 0.2326
# Epoch 53/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2576 - mean_absolute_error: 0.2810 - val_loss: 0.1373 - val_mean_absolute_error: 0.3050
# Epoch 54/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2468 - mean_absolute_error: 0.2799 - val_loss: 0.2444 - val_mean_absolute_error: 0.4215
# Epoch 55/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2295 - mean_absolute_error: 0.2605 - val_loss: 0.0644 - val_mean_absolute_error: 0.1864
# Epoch 56/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2468 - mean_absolute_error: 0.2759 - val_loss: 0.1065 - val_mean_absolute_error: 0.2509
# Epoch 57/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2786 - mean_absolute_error: 0.2982 - val_loss: 0.0658 - val_mean_absolute_error: 0.1893
# Epoch 58/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2502 - mean_absolute_error: 0.2775 - val_loss: 0.0685 - val_mean_absolute_error: 0.1936
# Epoch 59/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2294 - mean_absolute_error: 0.2615 - val_loss: 0.0723 - val_mean_absolute_error: 0.1986
# Epoch 60/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2357 - mean_absolute_error: 0.2654 - val_loss: 0.1522 - val_mean_absolute_error: 0.3256
# Epoch 61/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2423 - mean_absolute_error: 0.2713 - val_loss: 0.0667 - val_mean_absolute_error: 0.1900
# Epoch 62/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2527 - mean_absolute_error: 0.2767 - val_loss: 0.0649 - val_mean_absolute_error: 0.1866
# Epoch 63/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2416 - mean_absolute_error: 0.2706 - val_loss: 0.0779 - val_mean_absolute_error: 0.2098
# Epoch 64/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2320 - mean_absolute_error: 0.2629 - val_loss: 0.1465 - val_mean_absolute_error: 0.3062
# Epoch 65/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2490 - mean_absolute_error: 0.2780 - val_loss: 0.0703 - val_mean_absolute_error: 0.1973
# Epoch 66/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2354 - mean_absolute_error: 0.2686 - val_loss: 0.0774 - val_mean_absolute_error: 0.2092
# Epoch 67/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2347 - mean_absolute_error: 0.2709 - val_loss: 0.0853 - val_mean_absolute_error: 0.2244
# Epoch 68/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2304 - mean_absolute_error: 0.2633 - val_loss: 0.0824 - val_mean_absolute_error: 0.2186
# Epoch 69/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2375 - mean_absolute_error: 0.2698 - val_loss: 0.0905 - val_mean_absolute_error: 0.2281
# Epoch 70/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2435 - mean_absolute_error: 0.2726 - val_loss: 0.1243 - val_mean_absolute_error: 0.2881
# Epoch 71/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2285 - mean_absolute_error: 0.2628 - val_loss: 0.0931 - val_mean_absolute_error: 0.2368
# Epoch 72/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2420 - mean_absolute_error: 0.2714 - val_loss: 0.0655 - val_mean_absolute_error: 0.1879
# Epoch 73/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2391 - mean_absolute_error: 0.2677 - val_loss: 0.0706 - val_mean_absolute_error: 0.1979
# Epoch 74/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2476 - mean_absolute_error: 0.2728 - val_loss: 0.1007 - val_mean_absolute_error: 0.2501
# Epoch 75/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2422 - mean_absolute_error: 0.2747 - val_loss: 0.0997 - val_mean_absolute_error: 0.2511
# Epoch 76/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2317 - mean_absolute_error: 0.2627 - val_loss: 0.2712 - val_mean_absolute_error: 0.4624
# Epoch 77/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2445 - mean_absolute_error: 0.2714 - val_loss: 0.0655 - val_mean_absolute_error: 0.1879
# Epoch 78/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2316 - mean_absolute_error: 0.2663 - val_loss: 0.0689 - val_mean_absolute_error: 0.1941
# Epoch 79/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2346 - mean_absolute_error: 0.2650 - val_loss: 0.0734 - val_mean_absolute_error: 0.2028
# Epoch 80/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2389 - mean_absolute_error: 0.2695 - val_loss: 0.0782 - val_mean_absolute_error: 0.2087
# Epoch 81/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2404 - mean_absolute_error: 0.2708 - val_loss: 0.1102 - val_mean_absolute_error: 0.2649
# Epoch 82/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2371 - mean_absolute_error: 0.2685 - val_loss: 0.0691 - val_mean_absolute_error: 0.1972
# Epoch 83/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2313 - mean_absolute_error: 0.2628 - val_loss: 0.0660 - val_mean_absolute_error: 0.1899
# Epoch 84/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2350 - mean_absolute_error: 0.2650 - val_loss: 0.0657 - val_mean_absolute_error: 0.1882
# Epoch 85/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2352 - mean_absolute_error: 0.2641 - val_loss: 0.0654 - val_mean_absolute_error: 0.1880
# Epoch 86/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2490 - mean_absolute_error: 0.2750 - val_loss: 0.0888 - val_mean_absolute_error: 0.2273
# Epoch 87/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2280 - mean_absolute_error: 0.2588 - val_loss: 0.0825 - val_mean_absolute_error: 0.2216
# Epoch 88/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2463 - mean_absolute_error: 0.2723 - val_loss: 0.0740 - val_mean_absolute_error: 0.2029
# Epoch 89/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2291 - mean_absolute_error: 0.2606 - val_loss: 0.0671 - val_mean_absolute_error: 0.1908
# Epoch 90/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2361 - mean_absolute_error: 0.2649 - val_loss: 0.0673 - val_mean_absolute_error: 0.1917
# Epoch 91/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2398 - mean_absolute_error: 0.2678 - val_loss: 0.0655 - val_mean_absolute_error: 0.1888
# Epoch 92/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2357 - mean_absolute_error: 0.2657 - val_loss: 0.0647 - val_mean_absolute_error: 0.1861
# Epoch 93/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2345 - mean_absolute_error: 0.2657 - val_loss: 0.1047 - val_mean_absolute_error: 0.2501
# Epoch 94/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2350 - mean_absolute_error: 0.2688 - val_loss: 0.0679 - val_mean_absolute_error: 0.1925
# Epoch 95/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2553 - mean_absolute_error: 0.2790 - val_loss: 0.1041 - val_mean_absolute_error: 0.2515
# Epoch 96/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2242 - mean_absolute_error: 0.2577 - val_loss: 0.0682 - val_mean_absolute_error: 0.1935
# Epoch 97/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2275 - mean_absolute_error: 0.2623 - val_loss: 0.0677 - val_mean_absolute_error: 0.1931
# Epoch 98/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2236 - mean_absolute_error: 0.2560 - val_loss: 0.0686 - val_mean_absolute_error: 0.1919
# Epoch 99/100
# 304/304 [==============================] - 1s 3ms/step - loss: 0.2410 - mean_absolute_error: 0.2685 - val_loss: 0.1075 - val_mean_absolute_error: 0.2607
# Epoch 100/100
# 304/304 [==============================] - 1s 2ms/step - loss: 0.2318 - mean_absolute_error: 0.2597 - val_loss: 0.0648 - val_mean_absolute_error: 0.1865

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
y_pred_val = model.predict(X_val)
mse_val=mean_squared_error(y_val, y_pred_val)
print('mse_val:',mse_val)
y_pred_test = model.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# 304/304 [==============================] - 0s 951us/step
# 38/38 [==============================] - 0s 1ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16908\2060038512.py in <module>
#       5 plt.legend(['Training Predictions', 'Training Observations'])
#       6 y_pred_val = model.predict(X_val)
# ----> 7 mse_val=mean_squared_error(y_val, y_pred_val)
#       8 print('mse_val:',mse_val)
#       9 y_pred_test = model.predict(X_test)
#
# NameError: name 'mean_squared_error' is not defined

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 38/38 [==============================] - 0s 1ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 38/38 [==============================] - 0s 973us/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout, Conv1D
from keras.callbacks import ModelCheckpoint
NN_model = Sequential()
Dropout_ratio=0.1

# The Input Layer :
NN_model.add(Dense(16, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(32, kernel_initializer='normal',activation='relu'))
NN_model.add(Dropout(Dropout_ratio))
NN_model.add(Dense(64, kernel_initializer='normal',activation='relu'))
NN_model.add(Dropout(Dropout_ratio))
NN_model.add(Dense(64, kernel_initializer='normal',activation='relu'))
NN_model.add(Dropout(Dropout_ratio))




# tf.keras.optimizers.Adam(learning_rate=0.00007)
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
# NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
# NN_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

NN_model.fit(X_train,y_train,epochs=10)
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5'
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]


y_pred_valid = NN_model.predict(X_val)

mse_valid=mean_squared_error(y_val, y_pred_valid)
print('mse_valid:',mse_valid)

y_pred_test = NN_model.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 16)                64
#
#  dense_14 (Dense)            (None, 32)                544
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_15 (Dense)            (None, 64)                2112
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_17 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 6,945
# Trainable params: 6,945
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 304/304 [==============================] - 1s 1ms/step - loss: 70.6314 - mean_squared_error: 70.6314
# Epoch 2/10
# 304/304 [==============================] - 0s 1ms/step - loss: 6.4930 - mean_squared_error: 6.4930
# Epoch 3/10
# 304/304 [==============================] - 0s 1ms/step - loss: 5.8232 - mean_squared_error: 5.8232
# Epoch 4/10
# 304/304 [==============================] - 0s 1ms/step - loss: 5.1974 - mean_squared_error: 5.1974
# Epoch 5/10
# 304/304 [==============================] - 0s 1ms/step - loss: 4.4454 - mean_squared_error: 4.4454
# Epoch 6/10
# 304/304 [==============================] - 0s 1ms/step - loss: 3.9037 - mean_squared_error: 3.9037
# Epoch 7/10
# 304/304 [==============================] - 0s 1ms/step - loss: 4.0976 - mean_squared_error: 4.0976
# Epoch 8/10
# 304/304 [==============================] - 0s 1ms/step - loss: 3.9417 - mean_squared_error: 3.9417
# Epoch 9/10
# 304/304 [==============================] - 0s 1ms/step - loss: 3.8440 - mean_squared_error: 3.8440
# Epoch 10/10
# 304/304 [==============================] - 0s 1ms/step - loss: 3.7751 - mean_squared_error: 3.7751
# 38/38 [==============================] - 0s 703us/step
# mse_valid: 0.5425934
# 38/38 [==============================] - 0s 784us/step
# mse_test: 2.4471962

# %%
train_predictions = NN_model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 304/304 [==============================] - 0s 535us/step

# %%
val_predictions = NN_model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 38/38 [==============================] - 0s 730us/step

# %%
test_predictions = NN_model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 38/38 [==============================] - 0s 973us/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
CNN_model = Sequential()
CNN_model.add(Conv1D(32, 2, activation="relu", input_shape=(3, 1)))
CNN_model.add(Flatten())
CNN_model.add(Dense(64, activation="relu"))
CNN_model.add(Dense(1))
CNN_model.compile(loss="mse", optimizer="adam")
 
CNN_model.summary()
CNN_model.fit(X_train,y_train,epochs=30)



y_pred_valid = CNN_model.predict(X_val)

mse_valid=mean_squared_error(y_val, y_pred_valid)
print('mse_valid:',mse_valid)

y_pred_test = CNN_model.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2, 32)             96
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense_18 (Dense)            (None, 64)                4160
#
#  dense_19 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 4,321
# Trainable params: 4,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 304/304 [==============================] - 1s 881us/step - loss: 13.0660
# Epoch 2/30
# 304/304 [==============================] - 0s 825us/step - loss: 0.3116
# Epoch 3/30
# 304/304 [==============================] - 0s 865us/step - loss: 0.2990
# Epoch 4/30
# 304/304 [==============================] - 0s 911us/step - loss: 0.2865
# Epoch 5/30
# 304/304 [==============================] - 0s 878us/step - loss: 0.2691
# Epoch 6/30
# 304/304 [==============================] - 0s 845us/step - loss: 0.2476
# Epoch 7/30
# 304/304 [==============================] - 0s 842us/step - loss: 0.2338
# Epoch 8/30
# 304/304 [==============================] - 0s 914us/step - loss: 0.2352
# Epoch 9/30
# 304/304 [==============================] - 0s 851us/step - loss: 0.2448
# Epoch 10/30
# 304/304 [==============================] - 0s 861us/step - loss: 0.2357
# Epoch 11/30
# 304/304 [==============================] - 0s 832us/step - loss: 0.2312
# Epoch 12/30
# 304/304 [==============================] - 0s 884us/step - loss: 0.2224
# Epoch 13/30
# 304/304 [==============================] - 0s 914us/step - loss: 0.2280
# Epoch 14/30
# 304/304 [==============================] - 0s 898us/step - loss: 0.2480
# Epoch 15/30
# 304/304 [==============================] - 0s 868us/step - loss: 0.2291
# Epoch 16/30
# 304/304 [==============================] - 0s 865us/step - loss: 0.2256
# Epoch 17/30
# 304/304 [==============================] - 0s 875us/step - loss: 0.2301
# Epoch 18/30
# 304/304 [==============================] - 0s 848us/step - loss: 0.2290
# Epoch 19/30
# 304/304 [==============================] - 0s 898us/step - loss: 0.2438
# Epoch 20/30
# 304/304 [==============================] - 0s 838us/step - loss: 0.2450
# Epoch 21/30
# 304/304 [==============================] - 0s 898us/step - loss: 0.2402
# Epoch 22/30
# 304/304 [==============================] - 0s 917us/step - loss: 0.2418
# Epoch 23/30
# 304/304 [==============================] - 0s 868us/step - loss: 0.2262
# Epoch 24/30
# 304/304 [==============================] - 0s 822us/step - loss: 0.2624
# Epoch 25/30
# 304/304 [==============================] - 0s 861us/step - loss: 0.2252
# Epoch 26/30
# 304/304 [==============================] - 0s 888us/step - loss: 0.2303
# Epoch 27/30
# 304/304 [==============================] - 0s 934us/step - loss: 0.2208
# Epoch 28/30
# 304/304 [==============================] - 0s 828us/step - loss: 0.2434
# Epoch 29/30
# 304/304 [==============================] - 0s 828us/step - loss: 0.2334
# Epoch 30/30
# 304/304 [==============================] - 0s 845us/step - loss: 0.2312
# 38/38 [==============================] - 0s 784us/step
# mse_valid: 0.06586566
# 38/38 [==============================] - 0s 838us/step
# mse_test: 0.38146105

# %%
train_predictions = CNN_model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 304/304 [==============================] - 0s 673us/step

# %%
val_predictions = CNN_model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 38/38 [==============================] - 0s 541us/step

# %%
test_predictions = CNN_model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 38/38 [==============================] - 0s 838us/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
import random, os, sys
import numpy as np
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras import backend as K
import tensorflow as tf
from tensorflow.python.keras.layers import Layer

try:
    from dataloader import TokenList, pad_to_longest
    # for transformer
except: pass


EPOCHS = 10  # how many passes through our data
BATCH_SIZE = 16  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
embed_size = 60
SEQ_LEN=3
class LayerNormalization(Layer):
    def __init__(self, eps=1e-6, **kwargs):
        self.eps = eps
        super(LayerNormalization, self).__init__(**kwargs)
    def build(self, input_shape):
        self.gamma = self.add_weight(name='gamma', shape=input_shape[-1:],
                                     initializer=Ones(), trainable=True)
        self.beta = self.add_weight(name='beta', shape=input_shape[-1:],
                                    initializer=Zeros(), trainable=True)
        super(LayerNormalization, self).build(input_shape)
    def call(self, x):
        mean = K.mean(x, axis=-1, keepdims=True)
        std = K.std(x, axis=-1, keepdims=True)
        return self.gamma * (x - mean) / (std + self.eps) + self.beta
    def compute_output_shape(self, input_shape):
        return input_shape

class ScaledDotProductAttention():
    def __init__(self, d_model, attn_dropout=0.1):
        self.temper = np.sqrt(d_model)
        self.dropout = Dropout(attn_dropout)
    def __call__(self, q, k, v, mask):
        attn = Lambda(lambda x:K.batch_dot(x[0],x[1],axes=[2,2])/self.temper)([q, k])
        if mask is not None:
            mmask = Lambda(lambda x:(-1e+10)*(1-x))(mask)
            attn = Add()([attn, mmask])
        attn = Activation('softmax')(attn)
        attn = self.dropout(attn)
        output = Lambda(lambda x:K.batch_dot(x[0], x[1]))([attn, v])
        return output, attn

class MultiHeadAttention():
    # mode 0 - big martixes, faster; mode 1 - more clear implementation
    def __init__(self, n_head, d_model, d_k, d_v, dropout, mode=0, use_norm=True):
        self.mode = mode
        self.n_head = n_head
        self.d_k = d_k
        self.d_v = d_v
        self.dropout = dropout
        if mode == 0:
            self.qs_layer = Dense(n_head*d_k, use_bias=False)
            self.ks_layer = Dense(n_head*d_k, use_bias=False)
            self.vs_layer = Dense(n_head*d_v, use_bias=False)
        elif mode == 1:
            self.qs_layers = []
            self.ks_layers = []
            self.vs_layers = []
            for _ in range(n_head):
                self.qs_layers.append(TimeDistributed(Dense(d_k, use_bias=False)))
                self.ks_layers.append(TimeDistributed(Dense(d_k, use_bias=False)))
                self.vs_layers.append(TimeDistributed(Dense(d_v, use_bias=False)))
        self.attention = ScaledDotProductAttention(d_model)
        self.layer_norm = LayerNormalization() if use_norm else None
        self.w_o = TimeDistributed(Dense(d_model))

    def __call__(self, q, k, v, mask=None):
        d_k, d_v = self.d_k, self.d_v
        n_head = self.n_head

        if self.mode == 0:
            qs = self.qs_layer(q)  # [batch_size, len_q, n_head*d_k]
            ks = self.ks_layer(k)
            vs = self.vs_layer(v)

            def reshape1(x):
                s = tf.shape(x)   # [batch_size, len_q, n_head * d_k]
                x = tf.reshape(x, [s[0], s[1], n_head, d_k])
                x = tf.transpose(x, [2, 0, 1, 3])  
                x = tf.reshape(x, [-1, s[1], d_k])  # [n_head * batch_size, len_q, d_k]
                return x
            qs = Lambda(reshape1)(qs)
            ks = Lambda(reshape1)(ks)
            vs = Lambda(reshape1)(vs)

            if mask is not None:
                mask = Lambda(lambda x:K.repeat_elements(x, n_head, 0))(mask)
            head, attn = self.attention(qs, ks, vs, mask=mask)  
                
            def reshape2(x):
                s = tf.shape(x)   # [n_head * batch_size, len_v, d_v]
                x = tf.reshape(x, [n_head, -1, s[1], s[2]]) 
                x = tf.transpose(x, [1, 2, 0, 3])
                x = tf.reshape(x, [-1, s[1], n_head*d_v])  # [batch_size, len_v, n_head * d_v]
                return x
            head = Lambda(reshape2)(head)
        elif self.mode == 1:
            heads = []; attns = []
            for i in range(n_head):
                qs = self.qs_layers[i](q)   
                ks = self.ks_layers[i](k) 
                vs = self.vs_layers[i](v) 
                head, attn = self.attention(qs, ks, vs, mask)
                heads.append(head); attns.append(attn)
            head = Concatenate()(heads) if n_head > 1 else heads[0]
            attn = Concatenate()(attns) if n_head > 1 else attns[0]

        outputs = self.w_o(head)
        outputs = Dropout(self.dropout)(outputs)
        if not self.layer_norm: return outputs, attn
        # outputs = Add()([outputs, q]) # sl: fix
        return self.layer_norm(outputs), attn

class PositionwiseFeedForward():
    def __init__(self, d_hid, d_inner_hid, dropout=0.1):
        self.w_1 = Conv1D(d_inner_hid, 1, activation='relu')
        self.w_2 = Conv1D(d_hid, 1)
        self.layer_norm = LayerNormalization()
        self.dropout = Dropout(dropout)
    def __call__(self, x):
        output = self.w_1(x) 
        output = self.w_2(output)
        output = self.dropout(output)
        output = Add()([output, x])
        return self.layer_norm(output)

class EncoderLayer():
    def __init__(self, d_model, d_inner_hid, n_head, d_k, d_v, dropout=0.1):
        self.self_att_layer = MultiHeadAttention(n_head, d_model, d_k, d_v, dropout=dropout)
        self.pos_ffn_layer  = PositionwiseFeedForward(d_model, d_inner_hid, dropout=dropout)
    def __call__(self, enc_input, mask=None):
        output, slf_attn = self.self_att_layer(enc_input, enc_input, enc_input, mask=mask)
        output = self.pos_ffn_layer(output)
        return output, slf_attn


def GetPosEncodingMatrix(max_len, d_emb):
    pos_enc = np.array([
        [pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)] 
        if pos != 0 else np.zeros(d_emb) 
            for pos in range(max_len)
            ])
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2]) # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2]) # dim 2i+1
    return pos_enc

def GetPadMask(q, k):
    ones = K.expand_dims(K.ones_like(q, 'float32'), -1)
    mask = K.cast(K.expand_dims(K.not_equal(k, 0), 1), 'float32')
    mask = K.batch_dot(ones, mask, axes=[2,1])
    return mask

def GetSubMask(s):
    len_s = tf.shape(s)[1]
    bs = tf.shape(s)[:1]
    mask = K.cumsum(tf.eye(len_s, batch_shape=bs), 1)
    return mask

class Transformer():
    def __init__(self, len_limit, embedding_matrix, d_model=embed_size, \
              d_inner_hid=512, n_head=10, d_k=64, d_v=64, layers=2, dropout=0.1, \
              share_word_emb=False, **kwargs):
        self.name = 'Transformer'
        self.len_limit = len_limit
        self.src_loc_info = False # True # sl: fix later
        self.d_model = d_model
        self.decode_model = None
        d_emb = d_model

        pos_emb = Embedding(len_limit, d_emb, trainable=False, \
                            weights=[GetPosEncodingMatrix(len_limit, d_emb)])

        i_word_emb = Embedding(max_features, d_emb, weights=[embedding_matrix]) # Add Kaggle provided embedding here

        self.encoder = Encoder(d_model, d_inner_hid, n_head, d_k, d_v, layers, dropout, \
                               word_emb=i_word_emb, pos_emb=pos_emb)

        
    def get_pos_seq(self, x):
        mask = K.cast(K.not_equal(x, 0), 'int32')
        pos = K.cumsum(K.ones_like(x, 'int32'), 1)
        return pos * mask

    def compile(self, active_layers=999):
        src_seq_input = Input(shape=(None, ))
        x = Embedding(max_features, embed_size, weights=[embedding_matrix])(src_seq_input)
        
        
        x, slf_attn = MultiHeadAttention(n_head=3, d_model=300, d_k=64, d_v=64, dropout=0.1)(x, x, x)
        
        avg_pool = GlobalAveragePooling1D()(x)
        max_pool = GlobalMaxPooling1D()(x)
        conc = concatenate([avg_pool, max_pool])
        conc = Dense(64, activation="relu")(conc)
        x = Dense(1)(conc)   
        
        
        self.model = Model(inputs=src_seq_input, outputs=x)
        self.model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=['accuracy'])

# %%
def build_model():
    Inp = Input(shape = (SEQ_LEN, 1))
    x = Dense(32, activation="relu")(Inp)
    
    out, slf_attn = MultiHeadAttention(n_head=2, d_model=32, d_k=8, d_v=8, dropout=0.1)(x,x,x)
    out = Dense(32, activation="relu")(out)
    x = x + out
    
    
    out, slf_attn = MultiHeadAttention(n_head=2, d_model=32, d_k=8, d_v=8, dropout=0.1)(x,x,x)
    out = Dense(32, activation="relu")(out)
    x = x + out
    
        
    avg_pool = GlobalAveragePooling1D()(x)
    conc = Dense(64, activation="relu")(avg_pool)
    x = Dense(1)(conc)      

    model = Model(inputs = Inp, outputs = x)
    model.compile(
        loss = "mean_squared_error", 
        #optimizer = Adam(lr = config["lr"], decay = config["lr_d"]), 
        optimizer = Adam(learning_rate=0.0005))
    
    # Save entire model to a HDF5 file
#     model.save('GE_stock_price_model.h5')
    
    return model

# %%
multi_head = build_model()
multi_head.summary()
multi_head.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=30,
                    validation_data=(X_val, y_val), 
                    #callbacks = [checkpoint , lr_reduce]
             )
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.__operators__.add_1), but are not present in its tracked objects:   <tf.Variable 'layer_normalization_1/beta:0' shape=(32,) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.__operators__.add_4), but are not present in its tracked objects:   <tf.Variable 'layer_normalization_2/beta:0' shape=(32,) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 3, 1)]       0           []
#
#  dense_25 (Dense)               (None, 3, 32)        64          ['input_3[0][0]']
#
#  dense_26 (Dense)               (None, 3, 16)        512         ['dense_25[0][0]']
#
#  dense_27 (Dense)               (None, 3, 16)        512         ['dense_25[0][0]']
#
#  lambda_6 (Lambda)              (None, 3, 8)         0           ['dense_26[0][0]']
#
#  lambda_7 (Lambda)              (None, 3, 8)         0           ['dense_27[0][0]']
#
#  lambda_9 (Lambda)              (None, 3, 3)         0           ['lambda_6[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  activation_1 (Activation)      (None, 3, 3)         0           ['lambda_9[0][0]']
#
#  dense_28 (Dense)               (None, 3, 16)        512         ['dense_25[0][0]']
#
#  dropout_11 (Dropout)           (None, 3, 3)         0           ['activation_1[0][0]']
#
#  lambda_8 (Lambda)              (None, 3, 8)         0           ['dense_28[0][0]']
#
#  lambda_10 (Lambda)             (None, 3, 8)         0           ['dropout_11[0][0]',
#                                                                   'lambda_8[0][0]']
#
#  lambda_11 (Lambda)             (None, 3, 16)        0           ['lambda_10[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 3, 32)       544         ['lambda_11[0][0]']
#  buted)
#
#  dropout_12 (Dropout)           (None, 3, 32)        0           ['time_distributed_1[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  (None, 3, 1)        0           ['dropout_12[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLambda)  (None, 3, 32)        0           ['dropout_12[0][0]',
#                                                                   'tf.math.reduce_mean[0][0]']
#
#  tf.math.reduce_std (TFOpLambda  (None, 3, 1)        0           ['dropout_12[0][0]']
#  )
#
#  tf.math.multiply (TFOpLambda)  (None, 3, 32)        0           ['tf.math.subtract[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 3, 1)        0           ['tf.math.reduce_std[0][0]']
#  da)
#
#  tf.math.truediv (TFOpLambda)   (None, 3, 32)        0           ['tf.math.multiply[0][0]',
#                                                                   'tf.__operators__.add[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 3, 32)       0           ['tf.math.truediv[0][0]']
#  mbda)
#
#  dense_30 (Dense)               (None, 3, 32)        1056        ['tf.__operators__.add_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 3, 32)       0           ['dense_25[0][0]',
#  mbda)                                                            'dense_30[0][0]']
#
#  dense_31 (Dense)               (None, 3, 16)        512         ['tf.__operators__.add_2[0][0]']
#
#  dense_32 (Dense)               (None, 3, 16)        512         ['tf.__operators__.add_2[0][0]']
#
#  lambda_12 (Lambda)             (None, 3, 8)         0           ['dense_31[0][0]']
#
#  lambda_13 (Lambda)             (None, 3, 8)         0           ['dense_32[0][0]']
#
#  lambda_15 (Lambda)             (None, 3, 3)         0           ['lambda_12[0][0]',
#                                                                   'lambda_13[0][0]']
#
#  activation_2 (Activation)      (None, 3, 3)         0           ['lambda_15[0][0]']
#
#  dense_33 (Dense)               (None, 3, 16)        512         ['tf.__operators__.add_2[0][0]']
#
#  dropout_13 (Dropout)           (None, 3, 3)         0           ['activation_2[0][0]']
#
#  lambda_14 (Lambda)             (None, 3, 8)         0           ['dense_33[0][0]']
#
#  lambda_16 (Lambda)             (None, 3, 8)         0           ['dropout_13[0][0]',
#                                                                   'lambda_14[0][0]']
#
#  lambda_17 (Lambda)             (None, 3, 16)        0           ['lambda_16[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 3, 32)       544         ['lambda_17[0][0]']
#  buted)
#
#  dropout_14 (Dropout)           (None, 3, 32)        0           ['time_distributed_2[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  (None, 3, 1)        0           ['dropout_14[0][0]']
#  bda)
#
#  tf.math.subtract_1 (TFOpLambda  (None, 3, 32)       0           ['dropout_14[0][0]',
#  )                                                                'tf.math.reduce_mean_1[0][0]']
#
#  tf.math.reduce_std_1 (TFOpLamb  (None, 3, 1)        0           ['dropout_14[0][0]']
#  da)
#
#  tf.math.multiply_1 (TFOpLambda  (None, 3, 32)       0           ['tf.math.subtract_1[0][0]']
#  )
#
#  tf.__operators__.add_3 (TFOpLa  (None, 3, 1)        0           ['tf.math.reduce_std_1[0][0]']
#  mbda)
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 3, 32)       0           ['tf.math.multiply_1[0][0]',
#                                                                   'tf.__operators__.add_3[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 3, 32)       0           ['tf.math.truediv_1[0][0]']
#  mbda)
#
#  dense_35 (Dense)               (None, 3, 32)        1056        ['tf.__operators__.add_4[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 3, 32)       0           ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'dense_35[0][0]']
#
#  global_average_pooling1d (Glob  (None, 32)          0           ['tf.__operators__.add_5[0][0]']
#  alAveragePooling1D)
#
#  dense_36 (Dense)               (None, 64)           2112        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_37 (Dense)               (None, 1)            65          ['dense_36[0][0]']
#
# ==================================================================================================
# Total params: 8,513
# Trainable params: 8,513
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 608/608 [==============================] - 4s 3ms/step - loss: 52.8412 - val_loss: 0.1786
# Epoch 2/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3991 - val_loss: 0.1106
# Epoch 3/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3672 - val_loss: 0.1098
# Epoch 4/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3515 - val_loss: 0.1143
# Epoch 5/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3495 - val_loss: 0.1069
# Epoch 6/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3382 - val_loss: 0.1113
# Epoch 7/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3389 - val_loss: 0.1279
# Epoch 8/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3561 - val_loss: 0.1064
# Epoch 9/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3549 - val_loss: 0.1204
# Epoch 10/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3411 - val_loss: 0.1261
# Epoch 11/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3400 - val_loss: 0.1630
# Epoch 12/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3582 - val_loss: 0.1365
# Epoch 13/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3439 - val_loss: 0.1052
# Epoch 14/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3471 - val_loss: 0.1241
# Epoch 15/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3404 - val_loss: 0.1040
# Epoch 16/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3415 - val_loss: 0.1089
# Epoch 17/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3569 - val_loss: 0.1852
# Epoch 18/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3454 - val_loss: 0.1159
# Epoch 19/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3430 - val_loss: 0.1047
# Epoch 20/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3352 - val_loss: 0.1150
# Epoch 21/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3311 - val_loss: 0.1046
# Epoch 22/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3311 - val_loss: 0.1186
# Epoch 23/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3385 - val_loss: 0.1037
# Epoch 24/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3544 - val_loss: 0.1076
# Epoch 25/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3356 - val_loss: 0.1217
# Epoch 26/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3360 - val_loss: 0.1356
# Epoch 27/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3352 - val_loss: 0.1047
# Epoch 28/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3409 - val_loss: 0.1576
# Epoch 29/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3363 - val_loss: 0.1490
# Epoch 30/30
# 608/608 [==============================] - 1s 2ms/step - loss: 0.3297 - val_loss: 0.1035

# %%
train_predictions = multi_head.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 304/304 [==============================] - 1s 868us/step

# %%
val_predictions = multi_head.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 38/38 [==============================] - 0s 1ms/step

# %%
test_predictions = multi_head.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 38/38 [==============================] - 0s 1ms/step

# %%
y_pred_test = multi_head.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# 38/38 [==============================] - 0s 1ms/step
# mse_test: 0.57593656

# %%
y_pred_test = multi_head.predict(X_test)
mse_val=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# 38/38 [==============================] - 0s 1ms/step
# mse_test: 0.57593656
