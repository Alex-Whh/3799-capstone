# %%
import pandas as pd
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
df = pd.read_csv('IBM.csv')

df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1962-01-02    7.374124    7.374124    7.291268    7.291268    1.633034
# 1      1962-01-03    7.291268    7.355003    7.291268    7.355003    1.647309
# 2      1962-01-04    7.355003    7.355003    7.278521    7.281708    1.630892
# 3      1962-01-05    7.272148    7.272148    7.125558    7.138305    1.598774
# 4      1962-01-08    7.131931    7.131931    6.947100    7.004461    1.568797
# ...           ...         ...         ...         ...         ...         ...
# 15323  2022-11-14  142.630005  146.080002  142.179993  144.199997  144.199997
# 15324  2022-11-15  144.080002  146.160004  142.000000  144.339996  144.339996
# 15325  2022-11-16  144.130005  144.949997  144.009995  144.520004  144.520004
# 15326  2022-11-17  143.410004  146.179993  143.250000  146.089996  146.089996
# 15327  2022-11-18  146.559998  148.309998  145.940002  147.639999  147.639999
#
#         Volume
# 0       407940
# 1       305955
# 2       274575
# 3       384405
# 4       572685
# ...        ...
# 15323  5293500
# 15324  4727100
# 15325  3445200
# 15326  3954000
# 15327  4659700
#
# [15328 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#              Date       Close
# 0      1962-01-02    7.291268
# 1      1962-01-03    7.355003
# 2      1962-01-04    7.281708
# 3      1962-01-05    7.138305
# 4      1962-01-08    7.004461
# ...           ...         ...
# 15323  2022-11-14  144.199997
# 15324  2022-11-15  144.339996
# 15325  2022-11-16  144.520004
# 15326  2022-11-17  146.089996
# 15327  2022-11-18  147.639999
#
# [15328 rows x 2 columns]

# %%
df['Date']
# Out:
# 0        1962-01-02
# 1        1962-01-03
# 2        1962-01-04
# 3        1962-01-05
# 4        1962-01-08
#             ...
# 15323    2022-11-14
# 15324    2022-11-15
# 15325    2022-11-16
# 15326    2022-11-17
# 15327    2022-11-18
# Name: Date, Length: 15328, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\Wu Honghao\AppData\Local\Temp\ipykernel_48764\2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0       1962-01-02
# 1       1962-01-03
# 2       1962-01-04
# 3       1962-01-05
# 4       1962-01-08
#            ...
# 15323   2022-11-14
# 15324   2022-11-15
# 15325   2022-11-16
# 15326   2022-11-17
# 15327   2022-11-18
# Name: Date, Length: 15328, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1962-01-02    7.291268
# 1962-01-03    7.355003
# 1962-01-04    7.281708
# 1962-01-05    7.138305
# 1962-01-08    7.004461
# ...                ...
# 2022-11-14  144.199997
# 2022-11-15  144.339996
# 2022-11-16  144.520004
# 2022-11-17  146.089996
# 2022-11-18  147.639999
#
# [15328 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np
import random 
random.seed(1)

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '1962-01-20', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#       Target Date    Target-3    Target-2    Target-1      Target
# 0      1962-01-20    7.144678    7.029955    7.049076    7.055449
# 1      1962-01-23    7.049076    7.055449    7.042702    6.972594
# 2      1962-01-24    7.055449    7.042702    6.972594    7.010835
# 3      1962-01-25    7.042702    6.972594    7.010835    6.934353
# 4      1962-01-26    6.972594    7.010835    6.934353    6.899299
# ...           ...         ...         ...         ...         ...
# 15142  2022-03-17  123.940002  125.639999  127.040001  127.959999
# 15143  2022-03-18  125.639999  127.040001  127.959999  128.759995
# 15144  2022-03-21  127.040001  127.959999  128.759995  128.100006
# 15145  2022-03-22  127.959999  128.759995  128.100006  129.059998
# 15146  2022-03-23  128.759995  128.100006  129.059998  128.300003
#
# [15147 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((15147,), (15147, 3, 1), (15147,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 379/379 [==============================] - 3s 3ms/step - loss: 396.1269 - mean_absolute_error: 7.2006 - val_loss: 1969.2462 - val_mean_absolute_error: 38.6740
# Epoch 2/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.5182 - mean_absolute_error: 0.6955 - val_loss: 1680.7744 - val_mean_absolute_error: 35.1356
# Epoch 3/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.4322 - mean_absolute_error: 0.6926 - val_loss: 1603.3937 - val_mean_absolute_error: 34.1774
# Epoch 4/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.4106 - mean_absolute_error: 0.6817 - val_loss: 1578.1544 - val_mean_absolute_error: 34.0300
# Epoch 5/100
# 379/379 [==============================] - 1s 3ms/step - loss: 1.2715 - mean_absolute_error: 0.6239 - val_loss: 1511.4254 - val_mean_absolute_error: 33.0139
# Epoch 6/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2435 - mean_absolute_error: 0.6378 - val_loss: 1492.1830 - val_mean_absolute_error: 33.0239
# Epoch 7/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2373 - mean_absolute_error: 0.6385 - val_loss: 1439.7037 - val_mean_absolute_error: 32.2217
# Epoch 8/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2425 - mean_absolute_error: 0.6338 - val_loss: 1417.1467 - val_mean_absolute_error: 32.3598
# Epoch 9/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2041 - mean_absolute_error: 0.6304 - val_loss: 1336.4602 - val_mean_absolute_error: 30.7593
# Epoch 10/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.3601 - mean_absolute_error: 0.6735 - val_loss: 1406.7466 - val_mean_absolute_error: 31.8049
# Epoch 11/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.3297 - mean_absolute_error: 0.6612 - val_loss: 1404.2909 - val_mean_absolute_error: 31.7569
# Epoch 12/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1946 - mean_absolute_error: 0.6108 - val_loss: 1359.7769 - val_mean_absolute_error: 31.1249
# Epoch 13/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2274 - mean_absolute_error: 0.6206 - val_loss: 1339.7065 - val_mean_absolute_error: 30.9537
# Epoch 14/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2426 - mean_absolute_error: 0.6410 - val_loss: 1362.8589 - val_mean_absolute_error: 31.2862
# Epoch 15/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.3152 - mean_absolute_error: 0.6620 - val_loss: 1456.0325 - val_mean_absolute_error: 32.6290
# Epoch 16/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2397 - mean_absolute_error: 0.6304 - val_loss: 1334.6465 - val_mean_absolute_error: 30.8033
# Epoch 17/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2513 - mean_absolute_error: 0.6378 - val_loss: 1400.8064 - val_mean_absolute_error: 31.8789
# Epoch 18/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2074 - mean_absolute_error: 0.6186 - val_loss: 1323.5017 - val_mean_absolute_error: 30.6098
# Epoch 19/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2846 - mean_absolute_error: 0.6434 - val_loss: 1449.2402 - val_mean_absolute_error: 32.4102
# Epoch 20/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2427 - mean_absolute_error: 0.6290 - val_loss: 1407.4752 - val_mean_absolute_error: 31.7941
# Epoch 21/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1744 - mean_absolute_error: 0.6073 - val_loss: 1331.6085 - val_mean_absolute_error: 30.7353
# Epoch 22/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1935 - mean_absolute_error: 0.6136 - val_loss: 1358.6068 - val_mean_absolute_error: 31.0628
# Epoch 23/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2085 - mean_absolute_error: 0.6217 - val_loss: 1356.4065 - val_mean_absolute_error: 31.0735
# Epoch 24/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2939 - mean_absolute_error: 0.6543 - val_loss: 1442.2229 - val_mean_absolute_error: 32.1803
# Epoch 25/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2563 - mean_absolute_error: 0.6289 - val_loss: 1468.1772 - val_mean_absolute_error: 32.5777
# Epoch 26/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2344 - mean_absolute_error: 0.6247 - val_loss: 1422.4785 - val_mean_absolute_error: 32.0111
# Epoch 27/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2316 - mean_absolute_error: 0.6206 - val_loss: 1472.9138 - val_mean_absolute_error: 32.7239
# Epoch 28/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1335 - mean_absolute_error: 0.5851 - val_loss: 1466.4314 - val_mean_absolute_error: 32.5413
# Epoch 29/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2399 - mean_absolute_error: 0.6404 - val_loss: 1442.7551 - val_mean_absolute_error: 32.2673
# Epoch 30/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1351 - mean_absolute_error: 0.5823 - val_loss: 1365.5269 - val_mean_absolute_error: 31.1482
# Epoch 31/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1665 - mean_absolute_error: 0.5944 - val_loss: 1368.0065 - val_mean_absolute_error: 31.1478
# Epoch 32/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.3019 - mean_absolute_error: 0.6336 - val_loss: 1376.5548 - val_mean_absolute_error: 31.2749
# Epoch 33/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2782 - mean_absolute_error: 0.6327 - val_loss: 1402.9376 - val_mean_absolute_error: 31.6223
# Epoch 34/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1957 - mean_absolute_error: 0.6100 - val_loss: 1413.4260 - val_mean_absolute_error: 31.8271
# Epoch 35/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1436 - mean_absolute_error: 0.5907 - val_loss: 1376.9308 - val_mean_absolute_error: 31.2542
# Epoch 36/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1638 - mean_absolute_error: 0.5983 - val_loss: 1437.3718 - val_mean_absolute_error: 32.1531
# Epoch 37/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1991 - mean_absolute_error: 0.6006 - val_loss: 1475.1172 - val_mean_absolute_error: 32.7794
# Epoch 38/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2475 - mean_absolute_error: 0.6387 - val_loss: 1534.4414 - val_mean_absolute_error: 33.5279
# Epoch 39/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1674 - mean_absolute_error: 0.5850 - val_loss: 1381.4482 - val_mean_absolute_error: 31.2977
# Epoch 40/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1560 - mean_absolute_error: 0.5828 - val_loss: 1378.5780 - val_mean_absolute_error: 31.2629
# Epoch 41/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1371 - mean_absolute_error: 0.5849 - val_loss: 1388.4274 - val_mean_absolute_error: 31.3901
# Epoch 42/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1193 - mean_absolute_error: 0.5677 - val_loss: 1489.8840 - val_mean_absolute_error: 32.7073
# Epoch 43/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1498 - mean_absolute_error: 0.5937 - val_loss: 1433.1116 - val_mean_absolute_error: 31.9667
# Epoch 44/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1563 - mean_absolute_error: 0.5829 - val_loss: 1396.9661 - val_mean_absolute_error: 31.5109
# Epoch 45/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1598 - mean_absolute_error: 0.5920 - val_loss: 1539.6942 - val_mean_absolute_error: 33.6966
# Epoch 46/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2566 - mean_absolute_error: 0.6242 - val_loss: 1517.7272 - val_mean_absolute_error: 33.4460
# Epoch 47/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1689 - mean_absolute_error: 0.5962 - val_loss: 1450.6805 - val_mean_absolute_error: 32.3487
# Epoch 48/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1340 - mean_absolute_error: 0.5809 - val_loss: 1437.2196 - val_mean_absolute_error: 32.2251
# Epoch 49/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1421 - mean_absolute_error: 0.5955 - val_loss: 1367.3480 - val_mean_absolute_error: 31.1557
# Epoch 50/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1133 - mean_absolute_error: 0.5801 - val_loss: 1396.5518 - val_mean_absolute_error: 31.5746
# Epoch 51/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1421 - mean_absolute_error: 0.5794 - val_loss: 1347.1152 - val_mean_absolute_error: 30.8798
# Epoch 52/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1552 - mean_absolute_error: 0.5876 - val_loss: 1338.6885 - val_mean_absolute_error: 30.7581
# Epoch 53/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2346 - mean_absolute_error: 0.6265 - val_loss: 1392.8228 - val_mean_absolute_error: 31.5080
# Epoch 54/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1657 - mean_absolute_error: 0.5953 - val_loss: 1442.0656 - val_mean_absolute_error: 32.2406
# Epoch 55/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1326 - mean_absolute_error: 0.5717 - val_loss: 1382.7939 - val_mean_absolute_error: 31.3120
# Epoch 56/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1209 - mean_absolute_error: 0.5686 - val_loss: 1465.9320 - val_mean_absolute_error: 32.7522
# Epoch 57/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1396 - mean_absolute_error: 0.5835 - val_loss: 1393.5197 - val_mean_absolute_error: 31.4506
# Epoch 58/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1207 - mean_absolute_error: 0.5785 - val_loss: 1392.4489 - val_mean_absolute_error: 31.4643
# Epoch 59/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1236 - mean_absolute_error: 0.5708 - val_loss: 1431.0620 - val_mean_absolute_error: 32.0784
# Epoch 60/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1202 - mean_absolute_error: 0.5817 - val_loss: 1426.4924 - val_mean_absolute_error: 32.1628
# Epoch 61/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1101 - mean_absolute_error: 0.5771 - val_loss: 1354.7075 - val_mean_absolute_error: 30.9409
# Epoch 62/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1455 - mean_absolute_error: 0.5827 - val_loss: 1481.9818 - val_mean_absolute_error: 32.9654
# Epoch 63/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1132 - mean_absolute_error: 0.5693 - val_loss: 1438.0876 - val_mean_absolute_error: 32.2572
# Epoch 64/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1220 - mean_absolute_error: 0.5645 - val_loss: 1468.2867 - val_mean_absolute_error: 32.8039
# Epoch 65/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1423 - mean_absolute_error: 0.5863 - val_loss: 1358.6763 - val_mean_absolute_error: 31.0553
# Epoch 66/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1457 - mean_absolute_error: 0.5755 - val_loss: 1410.1804 - val_mean_absolute_error: 31.8601
# Epoch 67/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1854 - mean_absolute_error: 0.5952 - val_loss: 1466.9739 - val_mean_absolute_error: 32.9403
# Epoch 68/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1919 - mean_absolute_error: 0.5899 - val_loss: 1399.9675 - val_mean_absolute_error: 31.6805
# Epoch 69/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1178 - mean_absolute_error: 0.5702 - val_loss: 1368.9818 - val_mean_absolute_error: 31.3592
# Epoch 70/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1703 - mean_absolute_error: 0.5857 - val_loss: 1349.8510 - val_mean_absolute_error: 31.2392
# Epoch 71/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2558 - mean_absolute_error: 0.6164 - val_loss: 1401.5437 - val_mean_absolute_error: 31.8527
# Epoch 72/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1425 - mean_absolute_error: 0.5766 - val_loss: 1346.9067 - val_mean_absolute_error: 31.1957
# Epoch 73/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1534 - mean_absolute_error: 0.5800 - val_loss: 1380.3695 - val_mean_absolute_error: 31.6960
# Epoch 74/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1863 - mean_absolute_error: 0.6067 - val_loss: 1459.0455 - val_mean_absolute_error: 32.6917
# Epoch 75/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1062 - mean_absolute_error: 0.5668 - val_loss: 1404.3879 - val_mean_absolute_error: 31.8721
# Epoch 76/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1495 - mean_absolute_error: 0.5725 - val_loss: 1410.1022 - val_mean_absolute_error: 32.2203
# Epoch 77/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2170 - mean_absolute_error: 0.6049 - val_loss: 1345.0330 - val_mean_absolute_error: 31.0748
# Epoch 78/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1198 - mean_absolute_error: 0.5695 - val_loss: 1394.9227 - val_mean_absolute_error: 31.9392
# Epoch 79/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1372 - mean_absolute_error: 0.5729 - val_loss: 1438.0004 - val_mean_absolute_error: 32.4157
# Epoch 80/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1648 - mean_absolute_error: 0.5854 - val_loss: 1427.6035 - val_mean_absolute_error: 32.4711
# Epoch 81/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1624 - mean_absolute_error: 0.5926 - val_loss: 1407.9010 - val_mean_absolute_error: 32.0791
# Epoch 82/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1562 - mean_absolute_error: 0.5894 - val_loss: 1433.3199 - val_mean_absolute_error: 32.3974
# Epoch 83/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1410 - mean_absolute_error: 0.5783 - val_loss: 1336.4979 - val_mean_absolute_error: 31.2310
# Epoch 84/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.0976 - mean_absolute_error: 0.5550 - val_loss: 1369.4243 - val_mean_absolute_error: 31.5299
# Epoch 85/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.0855 - mean_absolute_error: 0.5455 - val_loss: 1324.5790 - val_mean_absolute_error: 30.9406
# Epoch 86/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.0682 - mean_absolute_error: 0.5518 - val_loss: 1289.6924 - val_mean_absolute_error: 30.4272
# Epoch 87/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1519 - mean_absolute_error: 0.5780 - val_loss: 1322.0994 - val_mean_absolute_error: 30.7962
# Epoch 88/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1001 - mean_absolute_error: 0.5557 - val_loss: 1376.7292 - val_mean_absolute_error: 31.6593
# Epoch 89/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.2194 - mean_absolute_error: 0.6064 - val_loss: 1359.6526 - val_mean_absolute_error: 31.4543
# Epoch 90/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1735 - mean_absolute_error: 0.5986 - val_loss: 1288.5200 - val_mean_absolute_error: 30.1260
# Epoch 91/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.0979 - mean_absolute_error: 0.5558 - val_loss: 1324.5181 - val_mean_absolute_error: 30.9189
# Epoch 92/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.0995 - mean_absolute_error: 0.5581 - val_loss: 1317.3843 - val_mean_absolute_error: 30.7373
# Epoch 93/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1511 - mean_absolute_error: 0.5832 - val_loss: 1325.4977 - val_mean_absolute_error: 31.0406
# Epoch 94/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1304 - mean_absolute_error: 0.5715 - val_loss: 1258.3715 - val_mean_absolute_error: 29.9282
# Epoch 95/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.0560 - mean_absolute_error: 0.5485 - val_loss: 1290.2776 - val_mean_absolute_error: 30.3926
# Epoch 96/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1737 - mean_absolute_error: 0.5894 - val_loss: 1324.9692 - val_mean_absolute_error: 31.0629
# Epoch 97/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1054 - mean_absolute_error: 0.5638 - val_loss: 1254.2440 - val_mean_absolute_error: 29.9762
# Epoch 98/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.0685 - mean_absolute_error: 0.5514 - val_loss: 1294.3358 - val_mean_absolute_error: 30.5769
# Epoch 99/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.1254 - mean_absolute_error: 0.5758 - val_loss: 1344.8284 - val_mean_absolute_error: 31.0572
# Epoch 100/100
# 379/379 [==============================] - 1s 2ms/step - loss: 1.0809 - mean_absolute_error: 0.5403 - val_loss: 1287.8193 - val_mean_absolute_error: 30.6216

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
y_pred_val = model.predict(X_val)
mse_val=mean_squared_error(y_val, y_pred_val)
print('mse_val:',mse_val)
y_pred_test = model.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# 379/379 [==============================] - 0s 902us/step
# 48/48 [==============================] - 0s 958us/step
# mse_val: 1287.8191
# 48/48 [==============================] - 0s 979us/step
# mse_test: 140.8911

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 48/48 [==============================] - 0s 1ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 48/48 [==============================] - 0s 1ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout, Conv1D
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from keras.callbacks import ModelCheckpoint
NN_model = Sequential()
Dropout_ratio=0.1

# The Input Layer :
NN_model.add(Dense(16, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(32, kernel_initializer='normal',activation='relu'))
NN_model.add(Dropout(Dropout_ratio))
NN_model.add(Dense(64, kernel_initializer='normal',activation='relu'))
NN_model.add(Dropout(Dropout_ratio))
NN_model.add(Dense(64, kernel_initializer='normal',activation='relu'))
NN_model.add(Dropout(Dropout_ratio))




# tf.keras.optimizers.Adam(learning_rate=0.00007)
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
# NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
# NN_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

NN_model.fit(X_train,y_train,epochs=10)
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5'
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]


y_pred_valid = NN_model.predict(X_val)

mse_valid=mean_squared_error(y_val, y_pred_valid)
print('mse_valid:',mse_valid)

y_pred_test = NN_model.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 16)                64
#
#  dense_4 (Dense)             (None, 32)                544
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_5 (Dense)             (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 6,945
# Trainable params: 6,945
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 379/379 [==============================] - 1s 1ms/step - loss: 286.2621 - mean_squared_error: 286.2621
# Epoch 2/10
# 379/379 [==============================] - 0s 1ms/step - loss: 32.3526 - mean_squared_error: 32.3526
# Epoch 3/10
# 379/379 [==============================] - 0s 1ms/step - loss: 24.2666 - mean_squared_error: 24.2666
# Epoch 4/10
# 379/379 [==============================] - 0s 1ms/step - loss: 19.9797 - mean_squared_error: 19.9797
# Epoch 5/10
# 379/379 [==============================] - 0s 1ms/step - loss: 19.5104 - mean_squared_error: 19.5104
# Epoch 6/10
# 379/379 [==============================] - 0s 1ms/step - loss: 18.6971 - mean_squared_error: 18.6971
# Epoch 7/10
# 379/379 [==============================] - 0s 1ms/step - loss: 18.5720 - mean_squared_error: 18.5720
# Epoch 8/10
# 379/379 [==============================] - 0s 1ms/step - loss: 18.2768 - mean_squared_error: 18.2768
# Epoch 9/10
# 379/379 [==============================] - 0s 1ms/step - loss: 18.6432 - mean_squared_error: 18.6432
# Epoch 10/10
# 379/379 [==============================] - 0s 1ms/step - loss: 17.4229 - mean_squared_error: 17.4229
# 48/48 [==============================] - 0s 702us/step
# mse_valid: 371.81955
# 48/48 [==============================] - 0s 745us/step
# mse_test: 249.16452

# %%
train_predictions = NN_model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 379/379 [==============================] - 0s 532us/step

# %%
val_predictions = NN_model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 48/48 [==============================] - 0s 808us/step

# %%
test_predictions = NN_model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 48/48 [==============================] - 0s 681us/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
CNN_model = Sequential()
CNN_model.add(Conv1D(32, 2, activation="relu", input_shape=(3, 1)))
CNN_model.add(Flatten())
CNN_model.add(Dense(64, activation="relu"))
CNN_model.add(Dense(1))
CNN_model.compile(loss="mse", optimizer="adam")
 
CNN_model.summary()
CNN_model.fit(X_train,y_train,epochs=30)



y_pred_valid = CNN_model.predict(X_val)

mse_valid=mean_squared_error(y_val, y_pred_valid)
print('mse_valid:',mse_valid)

y_pred_test = CNN_model.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2, 32)             96
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,321
# Trainable params: 4,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 379/379 [==============================] - 1s 878us/step - loss: 63.0040
# Epoch 2/30
# 379/379 [==============================] - 0s 913us/step - loss: 1.4068
# Epoch 3/30
# 379/379 [==============================] - 0s 833us/step - loss: 1.3804
# Epoch 4/30
# 379/379 [==============================] - 0s 849us/step - loss: 1.3879
# Epoch 5/30
# 379/379 [==============================] - 0s 905us/step - loss: 1.2830
# Epoch 6/30
# 379/379 [==============================] - 0s 902us/step - loss: 1.2492
# Epoch 7/30
# 379/379 [==============================] - 0s 860us/step - loss: 1.3017
# Epoch 8/30
# 379/379 [==============================] - 0s 855us/step - loss: 1.1589
# Epoch 9/30
# 379/379 [==============================] - 0s 974us/step - loss: 1.2472
# Epoch 10/30
# 379/379 [==============================] - 0s 934us/step - loss: 1.1140
# Epoch 11/30
# 379/379 [==============================] - 0s 902us/step - loss: 1.2901
# Epoch 12/30
# 379/379 [==============================] - 0s 926us/step - loss: 1.1067
# Epoch 13/30
# 379/379 [==============================] - 0s 979us/step - loss: 1.2624
# Epoch 14/30
# 379/379 [==============================] - 0s 894us/step - loss: 1.1147
# Epoch 15/30
# 379/379 [==============================] - 0s 907us/step - loss: 1.1907
# Epoch 16/30
# 379/379 [==============================] - 0s 892us/step - loss: 1.2805
# Epoch 17/30
# 379/379 [==============================] - 0s 979us/step - loss: 1.1308
# Epoch 18/30
# 379/379 [==============================] - 0s 876us/step - loss: 1.2074
# Epoch 19/30
# 379/379 [==============================] - 0s 918us/step - loss: 1.0896
# Epoch 20/30
# 379/379 [==============================] - 0s 807us/step - loss: 1.1416
# Epoch 21/30
# 379/379 [==============================] - 0s 952us/step - loss: 1.2197
# Epoch 22/30
# 379/379 [==============================] - 0s 839us/step - loss: 1.1043
# Epoch 23/30
# 379/379 [==============================] - 0s 852us/step - loss: 1.1224
# Epoch 24/30
# 379/379 [==============================] - 0s 841us/step - loss: 1.0980
# Epoch 25/30
# 379/379 [==============================] - 0s 921us/step - loss: 1.1293
# Epoch 26/30
# 379/379 [==============================] - 0s 868us/step - loss: 1.1637
# Epoch 27/30
# 379/379 [==============================] - 0s 823us/step - loss: 1.1425
# Epoch 28/30
# 379/379 [==============================] - 0s 849us/step - loss: 1.1750
# Epoch 29/30
# 379/379 [==============================] - 0s 889us/step - loss: 1.1299
# Epoch 30/30
# 379/379 [==============================] - 0s 897us/step - loss: 1.1561
# 48/48 [==============================] - 0s 660us/step
# mse_valid: 4.9247875
# 48/48 [==============================] - 0s 617us/step
# mse_test: 4.650915

# %%
train_predictions = CNN_model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 379/379 [==============================] - 0s 514us/step

# %%
val_predictions = CNN_model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 48/48 [==============================] - 0s 681us/step

# %%
test_predictions = CNN_model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 48/48 [==============================] - 0s 894us/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
import random, os, sys
import numpy as np
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras import backend as K
import tensorflow as tf
from tensorflow.python.keras.layers import Layer

try:
    from dataloader import TokenList, pad_to_longest
    # for transformer
except: pass


EPOCHS = 10  # how many passes through our data
BATCH_SIZE = 16  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
embed_size = 60
SEQ_LEN=3
class LayerNormalization(Layer):
    def __init__(self, eps=1e-6, **kwargs):
        self.eps = eps
        super(LayerNormalization, self).__init__(**kwargs)
    def build(self, input_shape):
        self.gamma = self.add_weight(name='gamma', shape=input_shape[-1:],
                                     initializer=Ones(), trainable=True)
        self.beta = self.add_weight(name='beta', shape=input_shape[-1:],
                                    initializer=Zeros(), trainable=True)
        super(LayerNormalization, self).build(input_shape)
    def call(self, x):
        mean = K.mean(x, axis=-1, keepdims=True)
        std = K.std(x, axis=-1, keepdims=True)
        return self.gamma * (x - mean) / (std + self.eps) + self.beta
    def compute_output_shape(self, input_shape):
        return input_shape

class ScaledDotProductAttention():
    def __init__(self, d_model, attn_dropout=0.1):
        self.temper = np.sqrt(d_model)
        self.dropout = Dropout(attn_dropout)
    def __call__(self, q, k, v, mask):
        attn = Lambda(lambda x:K.batch_dot(x[0],x[1],axes=[2,2])/self.temper)([q, k])
        if mask is not None:
            mmask = Lambda(lambda x:(-1e+10)*(1-x))(mask)
            attn = Add()([attn, mmask])
        attn = Activation('softmax')(attn)
        attn = self.dropout(attn)
        output = Lambda(lambda x:K.batch_dot(x[0], x[1]))([attn, v])
        return output, attn

class MultiHeadAttention():
    # mode 0 - big martixes, faster; mode 1 - more clear implementation
    def __init__(self, n_head, d_model, d_k, d_v, dropout, mode=0, use_norm=True):
        self.mode = mode
        self.n_head = n_head
        self.d_k = d_k
        self.d_v = d_v
        self.dropout = dropout
        if mode == 0:
            self.qs_layer = Dense(n_head*d_k, use_bias=False)
            self.ks_layer = Dense(n_head*d_k, use_bias=False)
            self.vs_layer = Dense(n_head*d_v, use_bias=False)
        elif mode == 1:
            self.qs_layers = []
            self.ks_layers = []
            self.vs_layers = []
            for _ in range(n_head):
                self.qs_layers.append(TimeDistributed(Dense(d_k, use_bias=False)))
                self.ks_layers.append(TimeDistributed(Dense(d_k, use_bias=False)))
                self.vs_layers.append(TimeDistributed(Dense(d_v, use_bias=False)))
        self.attention = ScaledDotProductAttention(d_model)
        self.layer_norm = LayerNormalization() if use_norm else None
        self.w_o = TimeDistributed(Dense(d_model))

    def __call__(self, q, k, v, mask=None):
        d_k, d_v = self.d_k, self.d_v
        n_head = self.n_head

        if self.mode == 0:
            qs = self.qs_layer(q)  # [batch_size, len_q, n_head*d_k]
            ks = self.ks_layer(k)
            vs = self.vs_layer(v)

            def reshape1(x):
                s = tf.shape(x)   # [batch_size, len_q, n_head * d_k]
                x = tf.reshape(x, [s[0], s[1], n_head, d_k])
                x = tf.transpose(x, [2, 0, 1, 3])  
                x = tf.reshape(x, [-1, s[1], d_k])  # [n_head * batch_size, len_q, d_k]
                return x
            qs = Lambda(reshape1)(qs)
            ks = Lambda(reshape1)(ks)
            vs = Lambda(reshape1)(vs)

            if mask is not None:
                mask = Lambda(lambda x:K.repeat_elements(x, n_head, 0))(mask)
            head, attn = self.attention(qs, ks, vs, mask=mask)  
                
            def reshape2(x):
                s = tf.shape(x)   # [n_head * batch_size, len_v, d_v]
                x = tf.reshape(x, [n_head, -1, s[1], s[2]]) 
                x = tf.transpose(x, [1, 2, 0, 3])
                x = tf.reshape(x, [-1, s[1], n_head*d_v])  # [batch_size, len_v, n_head * d_v]
                return x
            head = Lambda(reshape2)(head)
        elif self.mode == 1:
            heads = []; attns = []
            for i in range(n_head):
                qs = self.qs_layers[i](q)   
                ks = self.ks_layers[i](k) 
                vs = self.vs_layers[i](v) 
                head, attn = self.attention(qs, ks, vs, mask)
                heads.append(head); attns.append(attn)
            head = Concatenate()(heads) if n_head > 1 else heads[0]
            attn = Concatenate()(attns) if n_head > 1 else attns[0]

        outputs = self.w_o(head)
        outputs = Dropout(self.dropout)(outputs)
        if not self.layer_norm: return outputs, attn
        # outputs = Add()([outputs, q]) # sl: fix
        return self.layer_norm(outputs), attn

class PositionwiseFeedForward():
    def __init__(self, d_hid, d_inner_hid, dropout=0.1):
        self.w_1 = Conv1D(d_inner_hid, 1, activation='relu')
        self.w_2 = Conv1D(d_hid, 1)
        self.layer_norm = LayerNormalization()
        self.dropout = Dropout(dropout)
    def __call__(self, x):
        output = self.w_1(x) 
        output = self.w_2(output)
        output = self.dropout(output)
        output = Add()([output, x])
        return self.layer_norm(output)

class EncoderLayer():
    def __init__(self, d_model, d_inner_hid, n_head, d_k, d_v, dropout=0.1):
        self.self_att_layer = MultiHeadAttention(n_head, d_model, d_k, d_v, dropout=dropout)
        self.pos_ffn_layer  = PositionwiseFeedForward(d_model, d_inner_hid, dropout=dropout)
    def __call__(self, enc_input, mask=None):
        output, slf_attn = self.self_att_layer(enc_input, enc_input, enc_input, mask=mask)
        output = self.pos_ffn_layer(output)
        return output, slf_attn


def GetPosEncodingMatrix(max_len, d_emb):
    pos_enc = np.array([
        [pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)] 
        if pos != 0 else np.zeros(d_emb) 
            for pos in range(max_len)
            ])
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2]) # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2]) # dim 2i+1
    return pos_enc

def GetPadMask(q, k):
    ones = K.expand_dims(K.ones_like(q, 'float32'), -1)
    mask = K.cast(K.expand_dims(K.not_equal(k, 0), 1), 'float32')
    mask = K.batch_dot(ones, mask, axes=[2,1])
    return mask

def GetSubMask(s):
    len_s = tf.shape(s)[1]
    bs = tf.shape(s)[:1]
    mask = K.cumsum(tf.eye(len_s, batch_shape=bs), 1)
    return mask

class Transformer():
    def __init__(self, len_limit, embedding_matrix, d_model=embed_size, \
              d_inner_hid=512, n_head=10, d_k=64, d_v=64, layers=2, dropout=0.1, \
              share_word_emb=False, **kwargs):
        self.name = 'Transformer'
        self.len_limit = len_limit
        self.src_loc_info = False # True # sl: fix later
        self.d_model = d_model
        self.decode_model = None
        d_emb = d_model

        pos_emb = Embedding(len_limit, d_emb, trainable=False, \
                            weights=[GetPosEncodingMatrix(len_limit, d_emb)])

        i_word_emb = Embedding(max_features, d_emb, weights=[embedding_matrix]) # Add Kaggle provided embedding here

        self.encoder = Encoder(d_model, d_inner_hid, n_head, d_k, d_v, layers, dropout, \
                               word_emb=i_word_emb, pos_emb=pos_emb)

        
    def get_pos_seq(self, x):
        mask = K.cast(K.not_equal(x, 0), 'int32')
        pos = K.cumsum(K.ones_like(x, 'int32'), 1)
        return pos * mask

    def compile(self, active_layers=999):
        src_seq_input = Input(shape=(None, ))
        x = Embedding(max_features, embed_size, weights=[embedding_matrix])(src_seq_input)
        
        
        x, slf_attn = MultiHeadAttention(n_head=3, d_model=300, d_k=64, d_v=64, dropout=0.1)(x, x, x)
        
        avg_pool = GlobalAveragePooling1D()(x)
        max_pool = GlobalMaxPooling1D()(x)
        conc = concatenate([avg_pool, max_pool])
        conc = Dense(64, activation="relu")(conc)
        x = Dense(1)(conc)   
        
        
        self.model = Model(inputs=src_seq_input, outputs=x)
        self.model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=['accuracy'])

# %%
def build_model():
    Inp = Input(shape = (SEQ_LEN, 1))
    x = Dense(32, activation="relu")(Inp)
    
    out, slf_attn = MultiHeadAttention(n_head=2, d_model=32, d_k=8, d_v=8, dropout=0.1)(x,x,x)
    out = Dense(32, activation="relu")(out)
    x = x + out
    
    
    out, slf_attn = MultiHeadAttention(n_head=2, d_model=32, d_k=8, d_v=8, dropout=0.1)(x,x,x)
    out = Dense(32, activation="relu")(out)
    x = x + out
    
        
    avg_pool = GlobalAveragePooling1D()(x)
    conc = Dense(64, activation="relu")(avg_pool)
    x = Dense(1)(conc)      

    model = Model(inputs = Inp, outputs = x)
    model.compile(
        loss = "mean_squared_error", 
        #optimizer = Adam(lr = config["lr"], decay = config["lr_d"]), 
        optimizer = Adam(learning_rate=0.0005))
    
    # Save entire model to a HDF5 file
#     model.save('GE_stock_price_model.h5')
    
    return model

# %%
multi_head = build_model()
multi_head.summary()
multi_head.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=30,
                    validation_data=(X_val, y_val), 
                    #callbacks = [checkpoint , lr_reduce]
             )
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.__operators__.add_1), but are not present in its tracked objects:   <tf.Variable 'layer_normalization_1/beta:0' shape=(32,) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.__operators__.add_4), but are not present in its tracked objects:   <tf.Variable 'layer_normalization_2/beta:0' shape=(32,) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 3, 1)]       0           []
#
#  dense_15 (Dense)               (None, 3, 32)        64          ['input_3[0][0]']
#
#  dense_16 (Dense)               (None, 3, 16)        512         ['dense_15[0][0]']
#
#  dense_17 (Dense)               (None, 3, 16)        512         ['dense_15[0][0]']
#
#  lambda_6 (Lambda)              (None, 3, 8)         0           ['dense_16[0][0]']
#
#  lambda_7 (Lambda)              (None, 3, 8)         0           ['dense_17[0][0]']
#
#  lambda_9 (Lambda)              (None, 3, 3)         0           ['lambda_6[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  activation_1 (Activation)      (None, 3, 3)         0           ['lambda_9[0][0]']
#
#  dense_18 (Dense)               (None, 3, 16)        512         ['dense_15[0][0]']
#
#  dropout_5 (Dropout)            (None, 3, 3)         0           ['activation_1[0][0]']
#
#  lambda_8 (Lambda)              (None, 3, 8)         0           ['dense_18[0][0]']
#
#  lambda_10 (Lambda)             (None, 3, 8)         0           ['dropout_5[0][0]',
#                                                                   'lambda_8[0][0]']
#
#  lambda_11 (Lambda)             (None, 3, 16)        0           ['lambda_10[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 3, 32)       544         ['lambda_11[0][0]']
#  buted)
#
#  dropout_6 (Dropout)            (None, 3, 32)        0           ['time_distributed_1[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  (None, 3, 1)        0           ['dropout_6[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLambda)  (None, 3, 32)        0           ['dropout_6[0][0]',
#                                                                   'tf.math.reduce_mean[0][0]']
#
#  tf.math.reduce_std (TFOpLambda  (None, 3, 1)        0           ['dropout_6[0][0]']
#  )
#
#  tf.math.multiply (TFOpLambda)  (None, 3, 32)        0           ['tf.math.subtract[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 3, 1)        0           ['tf.math.reduce_std[0][0]']
#  da)
#
#  tf.math.truediv (TFOpLambda)   (None, 3, 32)        0           ['tf.math.multiply[0][0]',
#                                                                   'tf.__operators__.add[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 3, 32)       0           ['tf.math.truediv[0][0]']
#  mbda)
#
#  dense_20 (Dense)               (None, 3, 32)        1056        ['tf.__operators__.add_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 3, 32)       0           ['dense_15[0][0]',
#  mbda)                                                            'dense_20[0][0]']
#
#  dense_21 (Dense)               (None, 3, 16)        512         ['tf.__operators__.add_2[0][0]']
#
#  dense_22 (Dense)               (None, 3, 16)        512         ['tf.__operators__.add_2[0][0]']
#
#  lambda_12 (Lambda)             (None, 3, 8)         0           ['dense_21[0][0]']
#
#  lambda_13 (Lambda)             (None, 3, 8)         0           ['dense_22[0][0]']
#
#  lambda_15 (Lambda)             (None, 3, 3)         0           ['lambda_12[0][0]',
#                                                                   'lambda_13[0][0]']
#
#  activation_2 (Activation)      (None, 3, 3)         0           ['lambda_15[0][0]']
#
#  dense_23 (Dense)               (None, 3, 16)        512         ['tf.__operators__.add_2[0][0]']
#
#  dropout_7 (Dropout)            (None, 3, 3)         0           ['activation_2[0][0]']
#
#  lambda_14 (Lambda)             (None, 3, 8)         0           ['dense_23[0][0]']
#
#  lambda_16 (Lambda)             (None, 3, 8)         0           ['dropout_7[0][0]',
#                                                                   'lambda_14[0][0]']
#
#  lambda_17 (Lambda)             (None, 3, 16)        0           ['lambda_16[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 3, 32)       544         ['lambda_17[0][0]']
#  buted)
#
#  dropout_8 (Dropout)            (None, 3, 32)        0           ['time_distributed_2[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  (None, 3, 1)        0           ['dropout_8[0][0]']
#  bda)
#
#  tf.math.subtract_1 (TFOpLambda  (None, 3, 32)       0           ['dropout_8[0][0]',
#  )                                                                'tf.math.reduce_mean_1[0][0]']
#
#  tf.math.reduce_std_1 (TFOpLamb  (None, 3, 1)        0           ['dropout_8[0][0]']
#  da)
#
#  tf.math.multiply_1 (TFOpLambda  (None, 3, 32)       0           ['tf.math.subtract_1[0][0]']
#  )
#
#  tf.__operators__.add_3 (TFOpLa  (None, 3, 1)        0           ['tf.math.reduce_std_1[0][0]']
#  mbda)
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 3, 32)       0           ['tf.math.multiply_1[0][0]',
#                                                                   'tf.__operators__.add_3[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 3, 32)       0           ['tf.math.truediv_1[0][0]']
#  mbda)
#
#  dense_25 (Dense)               (None, 3, 32)        1056        ['tf.__operators__.add_4[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 3, 32)       0           ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'dense_25[0][0]']
#
#  global_average_pooling1d (Glob  (None, 32)          0           ['tf.__operators__.add_5[0][0]']
#  alAveragePooling1D)
#
#  dense_26 (Dense)               (None, 64)           2112        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_27 (Dense)               (None, 1)            65          ['dense_26[0][0]']
#
# ==================================================================================================
# Total params: 8,513
# Trainable params: 8,513
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 758/758 [==============================] - 3s 3ms/step - loss: 156.1164 - val_loss: 11.3511
# Epoch 2/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.4581 - val_loss: 13.6511
# Epoch 3/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.4746 - val_loss: 19.5208
# Epoch 4/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5053 - val_loss: 6.9054
# Epoch 5/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.4945 - val_loss: 7.8177
# Epoch 6/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5573 - val_loss: 8.7275
# Epoch 7/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5125 - val_loss: 10.1217
# Epoch 8/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5550 - val_loss: 7.1967
# Epoch 9/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5667 - val_loss: 6.6191
# Epoch 10/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5760 - val_loss: 7.5315
# Epoch 11/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5643 - val_loss: 7.5678
# Epoch 12/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5901 - val_loss: 7.1341
# Epoch 13/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5638 - val_loss: 8.0787
# Epoch 14/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5500 - val_loss: 6.2826
# Epoch 15/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5449 - val_loss: 7.5675
# Epoch 16/30
# 758/758 [==============================] - 1s 2ms/step - loss: 1.5335 - val_loss: 6.6536
# Epoch 17/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5991 - val_loss: 12.8752
# Epoch 18/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5064 - val_loss: 13.1841
# Epoch 19/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5465 - val_loss: 9.4367
# Epoch 20/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5158 - val_loss: 7.2679
# Epoch 21/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5049 - val_loss: 6.5998
# Epoch 22/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.4884 - val_loss: 6.7915
# Epoch 23/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5490 - val_loss: 7.2004
# Epoch 24/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5185 - val_loss: 10.1683
# Epoch 25/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.4932 - val_loss: 7.9966
# Epoch 26/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.4921 - val_loss: 12.0255
# Epoch 27/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.4733 - val_loss: 7.3161
# Epoch 28/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.5256 - val_loss: 6.3073
# Epoch 29/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.4925 - val_loss: 7.2018
# Epoch 30/30
# 758/758 [==============================] - 2s 2ms/step - loss: 1.4687 - val_loss: 6.6880

# %%
train_predictions = multi_head.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 379/379 [==============================] - 1s 1ms/step

# %%
val_predictions = multi_head.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 48/48 [==============================] - 0s 1ms/step

# %%
test_predictions = multi_head.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 48/48 [==============================] - 0s 1ms/step

# %%
y_pred_test = multi_head.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# 48/48 [==============================] - 0s 1ms/step
# mse_test: 6.14394

# %%
y_pred_test = multi_head.predict(X_test)
mse_val=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# 48/48 [==============================] - 0s 1ms/step
# mse_test: 6.14394
