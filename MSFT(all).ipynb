# %%
import pandas as pd
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060809
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062980
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064067
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062437
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061351
# ...          ...         ...         ...         ...         ...         ...
# 9244  2022-11-14  241.990005  243.910004  239.210007  241.550003  240.871185
# 9245  2022-11-15  245.660004  247.000000  240.029999  241.970001  241.290009
# 9246  2022-11-16  242.789993  243.800003  240.419998  241.729996  241.729996
# 9247  2022-11-17  237.779999  243.250000  237.630005  241.679993  241.679993
# 9248  2022-11-18  243.509995  243.740005  239.029999  241.220001  241.220001
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9244    31123300
# 9245    31390100
# 9246    24093300
# 9247    23123500
# 9248    27591800
#
# [9249 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9244  2022-11-14  241.550003
# 9245  2022-11-15  241.970001
# 9246  2022-11-16  241.729996
# 9247  2022-11-17  241.679993
# 9248  2022-11-18  241.220001
#
# [9249 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9244    2022-11-14
# 9245    2022-11-15
# 9246    2022-11-16
# 9247    2022-11-17
# 9248    2022-11-18
# Name: Date, Length: 9249, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\Wu Honghao\AppData\Local\Temp\ipykernel_34256\2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9244   2022-11-14
# 9245   2022-11-15
# 9246   2022-11-16
# 9247   2022-11-17
# 9248   2022-11-18
# Name: Date, Length: 9249, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2022-11-14  241.550003
# 2022-11-15  241.970001
# 2022-11-16  241.729996
# 2022-11-17  241.679993
# 2022-11-18  241.220001
#
# [9249 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np
import random 
random.seed(1)

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '1986-03-30', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     1986-03-30    0.090278    0.092014    0.094618    0.096354
# 1     1986-04-01    0.094618    0.096354    0.095486    0.094618
# 2     1986-04-02    0.096354    0.095486    0.094618    0.095486
# 3     1986-04-03    0.095486    0.094618    0.095486    0.096354
# 4     1986-04-04    0.094618    0.095486    0.096354    0.096354
# ...          ...         ...         ...         ...         ...
# 9066  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 9067  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 9068  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 9069  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 9070  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [9071 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((9071,), (9071, 3, 1), (9071,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 227/227 [==============================] - 3s 4ms/step - loss: 91.4752 - mean_absolute_error: 4.2712 - val_loss: 516.7937 - val_mean_absolute_error: 15.3589
# Epoch 2/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3749 - mean_absolute_error: 0.3335 - val_loss: 402.7679 - val_mean_absolute_error: 12.7021
# Epoch 3/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3138 - mean_absolute_error: 0.3154 - val_loss: 359.2929 - val_mean_absolute_error: 11.6726
# Epoch 4/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3371 - mean_absolute_error: 0.3407 - val_loss: 345.7590 - val_mean_absolute_error: 11.6439
# Epoch 5/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2958 - mean_absolute_error: 0.3134 - val_loss: 322.7808 - val_mean_absolute_error: 10.8929
# Epoch 6/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3141 - mean_absolute_error: 0.3256 - val_loss: 310.0838 - val_mean_absolute_error: 10.5141
# Epoch 7/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3150 - mean_absolute_error: 0.3263 - val_loss: 305.5634 - val_mean_absolute_error: 10.5505
# Epoch 8/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3204 - mean_absolute_error: 0.3336 - val_loss: 304.3428 - val_mean_absolute_error: 10.5268
# Epoch 9/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3055 - mean_absolute_error: 0.3212 - val_loss: 293.5500 - val_mean_absolute_error: 10.0970
# Epoch 10/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2951 - mean_absolute_error: 0.3175 - val_loss: 285.2792 - val_mean_absolute_error: 9.8888
# Epoch 11/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2822 - mean_absolute_error: 0.3059 - val_loss: 286.1949 - val_mean_absolute_error: 10.0799
# Epoch 12/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3183 - mean_absolute_error: 0.3309 - val_loss: 275.8307 - val_mean_absolute_error: 9.6526
# Epoch 13/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3242 - mean_absolute_error: 0.3388 - val_loss: 286.1964 - val_mean_absolute_error: 10.1174
# Epoch 14/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2885 - mean_absolute_error: 0.3130 - val_loss: 282.3884 - val_mean_absolute_error: 10.0537
# Epoch 15/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3492 - mean_absolute_error: 0.3571 - val_loss: 283.8035 - val_mean_absolute_error: 9.9943
# Epoch 16/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3221 - mean_absolute_error: 0.3371 - val_loss: 275.5209 - val_mean_absolute_error: 9.6817
# Epoch 17/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3248 - mean_absolute_error: 0.3407 - val_loss: 272.0337 - val_mean_absolute_error: 9.7547
# Epoch 18/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3290 - mean_absolute_error: 0.3449 - val_loss: 275.2701 - val_mean_absolute_error: 9.6682
# Epoch 19/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3098 - mean_absolute_error: 0.3237 - val_loss: 270.6729 - val_mean_absolute_error: 9.6573
# Epoch 20/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2934 - mean_absolute_error: 0.3165 - val_loss: 265.3586 - val_mean_absolute_error: 9.4565
# Epoch 21/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3170 - mean_absolute_error: 0.3295 - val_loss: 267.8336 - val_mean_absolute_error: 9.6091
# Epoch 22/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3183 - mean_absolute_error: 0.3371 - val_loss: 265.5719 - val_mean_absolute_error: 9.6535
# Epoch 23/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2902 - mean_absolute_error: 0.3145 - val_loss: 258.5039 - val_mean_absolute_error: 9.3129
# Epoch 24/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3200 - mean_absolute_error: 0.3440 - val_loss: 250.9122 - val_mean_absolute_error: 9.1039
# Epoch 25/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3201 - mean_absolute_error: 0.3376 - val_loss: 254.2674 - val_mean_absolute_error: 9.1492
# Epoch 26/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2880 - mean_absolute_error: 0.3117 - val_loss: 247.9203 - val_mean_absolute_error: 9.0530
# Epoch 27/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3170 - mean_absolute_error: 0.3357 - val_loss: 248.3013 - val_mean_absolute_error: 9.0836
# Epoch 28/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3322 - mean_absolute_error: 0.3444 - val_loss: 253.6981 - val_mean_absolute_error: 9.4528
# Epoch 29/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2952 - mean_absolute_error: 0.3203 - val_loss: 250.6249 - val_mean_absolute_error: 9.4086
# Epoch 30/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2864 - mean_absolute_error: 0.3123 - val_loss: 250.3857 - val_mean_absolute_error: 9.5181
# Epoch 31/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3337 - mean_absolute_error: 0.3458 - val_loss: 246.3327 - val_mean_absolute_error: 9.3695
# Epoch 32/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3171 - mean_absolute_error: 0.3331 - val_loss: 241.7084 - val_mean_absolute_error: 8.9070
# Epoch 33/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2889 - mean_absolute_error: 0.3095 - val_loss: 239.2738 - val_mean_absolute_error: 8.9197
# Epoch 34/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2947 - mean_absolute_error: 0.3223 - val_loss: 231.8835 - val_mean_absolute_error: 8.7369
# Epoch 35/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3458 - mean_absolute_error: 0.3547 - val_loss: 250.7082 - val_mean_absolute_error: 9.5103
# Epoch 36/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2919 - mean_absolute_error: 0.3183 - val_loss: 242.3364 - val_mean_absolute_error: 9.3741
# Epoch 37/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2851 - mean_absolute_error: 0.3118 - val_loss: 221.6047 - val_mean_absolute_error: 8.4001
# Epoch 38/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3189 - mean_absolute_error: 0.3367 - val_loss: 227.7018 - val_mean_absolute_error: 8.6405
# Epoch 39/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3172 - mean_absolute_error: 0.3357 - val_loss: 231.5572 - val_mean_absolute_error: 8.7629
# Epoch 40/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3188 - mean_absolute_error: 0.3366 - val_loss: 230.3625 - val_mean_absolute_error: 9.0687
# Epoch 41/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2905 - mean_absolute_error: 0.3148 - val_loss: 219.5864 - val_mean_absolute_error: 8.4965
# Epoch 42/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2998 - mean_absolute_error: 0.3233 - val_loss: 225.1397 - val_mean_absolute_error: 8.6044
# Epoch 43/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3071 - mean_absolute_error: 0.3300 - val_loss: 230.7253 - val_mean_absolute_error: 8.7648
# Epoch 44/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2904 - mean_absolute_error: 0.3141 - val_loss: 227.3878 - val_mean_absolute_error: 8.6027
# Epoch 45/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3080 - mean_absolute_error: 0.3279 - val_loss: 241.8314 - val_mean_absolute_error: 9.5719
# Epoch 46/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2966 - mean_absolute_error: 0.3188 - val_loss: 223.4967 - val_mean_absolute_error: 8.6338
# Epoch 47/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2959 - mean_absolute_error: 0.3203 - val_loss: 211.9708 - val_mean_absolute_error: 8.2220
# Epoch 48/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2909 - mean_absolute_error: 0.3140 - val_loss: 211.7751 - val_mean_absolute_error: 8.2871
# Epoch 49/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3203 - mean_absolute_error: 0.3393 - val_loss: 227.1764 - val_mean_absolute_error: 8.7404
# Epoch 50/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2962 - mean_absolute_error: 0.3189 - val_loss: 225.3738 - val_mean_absolute_error: 8.6277
# Epoch 51/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2832 - mean_absolute_error: 0.3060 - val_loss: 217.1551 - val_mean_absolute_error: 8.3842
# Epoch 52/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3041 - mean_absolute_error: 0.3257 - val_loss: 237.4144 - val_mean_absolute_error: 9.0479
# Epoch 53/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2915 - mean_absolute_error: 0.3146 - val_loss: 221.1530 - val_mean_absolute_error: 8.8050
# Epoch 54/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2925 - mean_absolute_error: 0.3179 - val_loss: 238.0208 - val_mean_absolute_error: 9.3442
# Epoch 55/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3136 - mean_absolute_error: 0.3328 - val_loss: 233.9279 - val_mean_absolute_error: 9.0253
# Epoch 56/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3005 - mean_absolute_error: 0.3230 - val_loss: 219.8299 - val_mean_absolute_error: 8.4313
# Epoch 57/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2819 - mean_absolute_error: 0.3089 - val_loss: 222.7441 - val_mean_absolute_error: 8.6075
# Epoch 58/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2841 - mean_absolute_error: 0.3080 - val_loss: 221.2432 - val_mean_absolute_error: 8.6445
# Epoch 59/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3095 - mean_absolute_error: 0.3295 - val_loss: 225.5438 - val_mean_absolute_error: 8.7410
# Epoch 60/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3208 - mean_absolute_error: 0.3386 - val_loss: 225.0969 - val_mean_absolute_error: 8.5500
# Epoch 61/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2863 - mean_absolute_error: 0.3098 - val_loss: 216.1217 - val_mean_absolute_error: 8.3938
# Epoch 62/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3059 - mean_absolute_error: 0.3270 - val_loss: 218.5850 - val_mean_absolute_error: 8.4541
# Epoch 63/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3106 - mean_absolute_error: 0.3293 - val_loss: 218.5044 - val_mean_absolute_error: 8.4268
# Epoch 64/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3031 - mean_absolute_error: 0.3218 - val_loss: 211.1633 - val_mean_absolute_error: 8.1504
# Epoch 65/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2945 - mean_absolute_error: 0.3148 - val_loss: 223.3679 - val_mean_absolute_error: 8.8513
# Epoch 66/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3060 - mean_absolute_error: 0.3275 - val_loss: 216.3368 - val_mean_absolute_error: 8.4457
# Epoch 67/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2880 - mean_absolute_error: 0.3116 - val_loss: 203.3800 - val_mean_absolute_error: 7.9615
# Epoch 68/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2754 - mean_absolute_error: 0.3021 - val_loss: 197.6935 - val_mean_absolute_error: 7.8792
# Epoch 69/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2970 - mean_absolute_error: 0.3163 - val_loss: 218.3589 - val_mean_absolute_error: 8.5569
# Epoch 70/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2904 - mean_absolute_error: 0.3158 - val_loss: 221.8435 - val_mean_absolute_error: 8.8869
# Epoch 71/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2937 - mean_absolute_error: 0.3184 - val_loss: 204.1186 - val_mean_absolute_error: 7.9678
# Epoch 72/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2837 - mean_absolute_error: 0.3116 - val_loss: 217.7328 - val_mean_absolute_error: 8.4220
# Epoch 73/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3041 - mean_absolute_error: 0.3209 - val_loss: 201.8944 - val_mean_absolute_error: 7.9133
# Epoch 74/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2760 - mean_absolute_error: 0.3011 - val_loss: 197.3971 - val_mean_absolute_error: 7.7881
# Epoch 75/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3042 - mean_absolute_error: 0.3219 - val_loss: 202.4003 - val_mean_absolute_error: 7.9446
# Epoch 76/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2885 - mean_absolute_error: 0.3120 - val_loss: 203.0562 - val_mean_absolute_error: 7.9934
# Epoch 77/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2982 - mean_absolute_error: 0.3224 - val_loss: 211.4104 - val_mean_absolute_error: 8.2703
# Epoch 78/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2961 - mean_absolute_error: 0.3147 - val_loss: 239.9342 - val_mean_absolute_error: 9.4409
# Epoch 79/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2877 - mean_absolute_error: 0.3098 - val_loss: 203.7221 - val_mean_absolute_error: 7.9860
# Epoch 80/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3046 - mean_absolute_error: 0.3260 - val_loss: 217.3611 - val_mean_absolute_error: 8.5240
# Epoch 81/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3117 - mean_absolute_error: 0.3266 - val_loss: 210.0326 - val_mean_absolute_error: 8.3403
# Epoch 82/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2919 - mean_absolute_error: 0.3140 - val_loss: 200.4690 - val_mean_absolute_error: 7.8792
# Epoch 83/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2864 - mean_absolute_error: 0.3087 - val_loss: 195.7591 - val_mean_absolute_error: 7.7899
# Epoch 84/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2960 - mean_absolute_error: 0.3199 - val_loss: 216.6314 - val_mean_absolute_error: 8.4758
# Epoch 85/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2853 - mean_absolute_error: 0.3084 - val_loss: 209.6383 - val_mean_absolute_error: 8.1571
# Epoch 86/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3007 - mean_absolute_error: 0.3229 - val_loss: 225.8172 - val_mean_absolute_error: 8.7554
# Epoch 87/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2908 - mean_absolute_error: 0.3099 - val_loss: 219.9250 - val_mean_absolute_error: 8.5567
# Epoch 88/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2965 - mean_absolute_error: 0.3200 - val_loss: 216.9920 - val_mean_absolute_error: 8.4326
# Epoch 89/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2887 - mean_absolute_error: 0.3113 - val_loss: 218.9112 - val_mean_absolute_error: 8.5224
# Epoch 90/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3184 - mean_absolute_error: 0.3303 - val_loss: 229.7941 - val_mean_absolute_error: 8.9550
# Epoch 91/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.3067 - mean_absolute_error: 0.3280 - val_loss: 218.6454 - val_mean_absolute_error: 8.6927
# Epoch 92/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3093 - mean_absolute_error: 0.3280 - val_loss: 223.7684 - val_mean_absolute_error: 8.7840
# Epoch 93/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2986 - mean_absolute_error: 0.3165 - val_loss: 213.1688 - val_mean_absolute_error: 8.3379
# Epoch 94/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3084 - mean_absolute_error: 0.3261 - val_loss: 201.3344 - val_mean_absolute_error: 7.9201
# Epoch 95/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2837 - mean_absolute_error: 0.3080 - val_loss: 204.9311 - val_mean_absolute_error: 8.0725
# Epoch 96/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.2800 - mean_absolute_error: 0.3041 - val_loss: 199.9401 - val_mean_absolute_error: 7.8617
# Epoch 97/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2857 - mean_absolute_error: 0.3132 - val_loss: 207.7160 - val_mean_absolute_error: 8.2556
# Epoch 98/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2815 - mean_absolute_error: 0.3037 - val_loss: 217.8162 - val_mean_absolute_error: 8.6695
# Epoch 99/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.2861 - mean_absolute_error: 0.3107 - val_loss: 199.9078 - val_mean_absolute_error: 7.9508
# Epoch 100/100
# 227/227 [==============================] - 1s 2ms/step - loss: 0.3006 - mean_absolute_error: 0.3226 - val_loss: 192.2544 - val_mean_absolute_error: 7.6075

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
y_pred_val = model.predict(X_val)
mse_val=mean_squared_error(y_val, y_pred_val)
print('mse_val:',mse_val)
y_pred_test = model.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# 227/227 [==============================] - 1s 903us/step
# 29/29 [==============================] - 0s 714us/step
# mse_val: 192.25441
# 29/29 [==============================] - 0s 750us/step
# mse_test: 25135.447

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 29/29 [==============================] - 0s 893us/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 29/29 [==============================] - 0s 1ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout, Conv1D
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from keras.callbacks import ModelCheckpoint
NN_model = Sequential()
Dropout_ratio=0.1

# The Input Layer :
NN_model.add(Dense(16, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(32, kernel_initializer='normal',activation='relu'))
NN_model.add(Dropout(Dropout_ratio))
NN_model.add(Dense(64, kernel_initializer='normal',activation='relu'))
NN_model.add(Dropout(Dropout_ratio))
NN_model.add(Dense(64, kernel_initializer='normal',activation='relu'))
NN_model.add(Dropout(Dropout_ratio))




# tf.keras.optimizers.Adam(learning_rate=0.00007)
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
# NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
# NN_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

NN_model.fit(X_train,y_train,epochs=10)
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5'
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]


y_pred_valid = NN_model.predict(X_val)

mse_valid=mean_squared_error(y_val, y_pred_valid)
print('mse_valid:',mse_valid)

y_pred_test = NN_model.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 16)                64
#
#  dense_4 (Dense)             (None, 32)                544
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_5 (Dense)             (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 6,945
# Trainable params: 6,945
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 227/227 [==============================] - 0s 1ms/step - loss: 108.4579 - mean_squared_error: 108.4579
# Epoch 2/10
# 227/227 [==============================] - 0s 1ms/step - loss: 7.5167 - mean_squared_error: 7.5167
# Epoch 3/10
# 227/227 [==============================] - 0s 1ms/step - loss: 6.2058 - mean_squared_error: 6.2058
# Epoch 4/10
# 227/227 [==============================] - 0s 1ms/step - loss: 5.2069 - mean_squared_error: 5.2069
# Epoch 5/10
# 227/227 [==============================] - 0s 1ms/step - loss: 4.7681 - mean_squared_error: 4.7681
# Epoch 6/10
# 227/227 [==============================] - 0s 1ms/step - loss: 4.5480 - mean_squared_error: 4.5480
# Epoch 7/10
# 227/227 [==============================] - 0s 1ms/step - loss: 4.4527 - mean_squared_error: 4.4527
# Epoch 8/10
# 227/227 [==============================] - 0s 1ms/step - loss: 4.3535 - mean_squared_error: 4.3535
# Epoch 9/10
# 227/227 [==============================] - 0s 1ms/step - loss: 4.0883 - mean_squared_error: 4.0883
# Epoch 10/10
# 227/227 [==============================] - 0s 1ms/step - loss: 4.1702 - mean_squared_error: 4.1702
# 29/29 [==============================] - 0s 750us/step
# mse_valid: 111.00827
# 29/29 [==============================] - 0s 642us/step
# mse_test: 1185.1624

# %%
train_predictions = NN_model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 227/227 [==============================] - 0s 593us/step

# %%
val_predictions = NN_model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 29/29 [==============================] - 0s 719us/step

# %%
test_predictions = NN_model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 29/29 [==============================] - 0s 786us/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
CNN_model = Sequential()
CNN_model.add(Conv1D(32, 2, activation="relu", input_shape=(3, 1)))
CNN_model.add(Flatten())
CNN_model.add(Dense(64, activation="relu"))
CNN_model.add(Dense(1))
CNN_model.compile(loss="mse", optimizer="adam")
 
CNN_model.summary()
CNN_model.fit(X_train,y_train,epochs=30)



y_pred_valid = CNN_model.predict(X_val)

mse_valid=mean_squared_error(y_val, y_pred_valid)
print('mse_valid:',mse_valid)

y_pred_test = CNN_model.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2, 32)             96
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,321
# Trainable params: 4,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 227/227 [==============================] - 0s 832us/step - loss: 24.1534
# Epoch 2/30
# 227/227 [==============================] - 0s 841us/step - loss: 0.4106
# Epoch 3/30
# 227/227 [==============================] - 0s 885us/step - loss: 0.4002
# Epoch 4/30
# 227/227 [==============================] - 0s 1ms/step - loss: 0.3877
# Epoch 5/30
# 227/227 [==============================] - 0s 1ms/step - loss: 0.3851
# Epoch 6/30
# 227/227 [==============================] - 0s 929us/step - loss: 0.3671
# Epoch 7/30
# 227/227 [==============================] - 0s 863us/step - loss: 0.3622
# Epoch 8/30
# 227/227 [==============================] - 0s 845us/step - loss: 0.3572
# Epoch 9/30
# 227/227 [==============================] - 0s 823us/step - loss: 0.3297
# Epoch 10/30
# 227/227 [==============================] - 0s 903us/step - loss: 0.3333
# Epoch 11/30
# 227/227 [==============================] - 0s 1ms/step - loss: 0.3074
# Epoch 12/30
# 227/227 [==============================] - 0s 885us/step - loss: 0.3016
# Epoch 13/30
# 227/227 [==============================] - 0s 876us/step - loss: 0.3016
# Epoch 14/30
# 227/227 [==============================] - 0s 836us/step - loss: 0.2924
# Epoch 15/30
# 227/227 [==============================] - 0s 845us/step - loss: 0.2883
# Epoch 16/30
# 227/227 [==============================] - 0s 823us/step - loss: 0.2972
# Epoch 17/30
# 227/227 [==============================] - 0s 823us/step - loss: 0.2949
# Epoch 18/30
# 227/227 [==============================] - 0s 1ms/step - loss: 0.2891
# Epoch 19/30
# 227/227 [==============================] - 0s 987us/step - loss: 0.3154
# Epoch 20/30
# 227/227 [==============================] - 0s 863us/step - loss: 0.2956
# Epoch 21/30
# 227/227 [==============================] - 0s 863us/step - loss: 0.2944
# Epoch 22/30
# 227/227 [==============================] - 0s 867us/step - loss: 0.2778
# Epoch 23/30
# 227/227 [==============================] - 0s 867us/step - loss: 0.2761
# Epoch 24/30
# 227/227 [==============================] - 0s 872us/step - loss: 0.2846
# Epoch 25/30
# 227/227 [==============================] - 0s 987us/step - loss: 0.2977
# Epoch 26/30
# 227/227 [==============================] - 0s 951us/step - loss: 0.2815
# Epoch 27/30
# 227/227 [==============================] - 0s 956us/step - loss: 0.2780
# Epoch 28/30
# 227/227 [==============================] - 0s 863us/step - loss: 0.3073
# Epoch 29/30
# 227/227 [==============================] - 0s 823us/step - loss: 0.2738
# Epoch 30/30
# 227/227 [==============================] - 0s 841us/step - loss: 0.2993
# 29/29 [==============================] - 0s 750us/step
# mse_valid: 1.8777224
# 29/29 [==============================] - 0s 607us/step
# mse_test: 23.31174

# %%
train_predictions = CNN_model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 227/227 [==============================] - 0s 580us/step

# %%
val_predictions = CNN_model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 29/29 [==============================] - 0s 714us/step

# %%
test_predictions = CNN_model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 29/29 [==============================] - 0s 500us/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
import random, os, sys
import numpy as np
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras import backend as K
import tensorflow as tf
from tensorflow.python.keras.layers import Layer

try:
    from dataloader import TokenList, pad_to_longest
    # for transformer
except: pass


EPOCHS = 10  # how many passes through our data
BATCH_SIZE = 16  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
embed_size = 60
SEQ_LEN=3
class LayerNormalization(Layer):
    def __init__(self, eps=1e-6, **kwargs):
        self.eps = eps
        super(LayerNormalization, self).__init__(**kwargs)
    def build(self, input_shape):
        self.gamma = self.add_weight(name='gamma', shape=input_shape[-1:],
                                     initializer=Ones(), trainable=True)
        self.beta = self.add_weight(name='beta', shape=input_shape[-1:],
                                    initializer=Zeros(), trainable=True)
        super(LayerNormalization, self).build(input_shape)
    def call(self, x):
        mean = K.mean(x, axis=-1, keepdims=True)
        std = K.std(x, axis=-1, keepdims=True)
        return self.gamma * (x - mean) / (std + self.eps) + self.beta
    def compute_output_shape(self, input_shape):
        return input_shape

class ScaledDotProductAttention():
    def __init__(self, d_model, attn_dropout=0.1):
        self.temper = np.sqrt(d_model)
        self.dropout = Dropout(attn_dropout)
    def __call__(self, q, k, v, mask):
        attn = Lambda(lambda x:K.batch_dot(x[0],x[1],axes=[2,2])/self.temper)([q, k])
        if mask is not None:
            mmask = Lambda(lambda x:(-1e+10)*(1-x))(mask)
            attn = Add()([attn, mmask])
        attn = Activation('softmax')(attn)
        attn = self.dropout(attn)
        output = Lambda(lambda x:K.batch_dot(x[0], x[1]))([attn, v])
        return output, attn

class MultiHeadAttention():
    # mode 0 - big martixes, faster; mode 1 - more clear implementation
    def __init__(self, n_head, d_model, d_k, d_v, dropout, mode=0, use_norm=True):
        self.mode = mode
        self.n_head = n_head
        self.d_k = d_k
        self.d_v = d_v
        self.dropout = dropout
        if mode == 0:
            self.qs_layer = Dense(n_head*d_k, use_bias=False)
            self.ks_layer = Dense(n_head*d_k, use_bias=False)
            self.vs_layer = Dense(n_head*d_v, use_bias=False)
        elif mode == 1:
            self.qs_layers = []
            self.ks_layers = []
            self.vs_layers = []
            for _ in range(n_head):
                self.qs_layers.append(TimeDistributed(Dense(d_k, use_bias=False)))
                self.ks_layers.append(TimeDistributed(Dense(d_k, use_bias=False)))
                self.vs_layers.append(TimeDistributed(Dense(d_v, use_bias=False)))
        self.attention = ScaledDotProductAttention(d_model)
        self.layer_norm = LayerNormalization() if use_norm else None
        self.w_o = TimeDistributed(Dense(d_model))

    def __call__(self, q, k, v, mask=None):
        d_k, d_v = self.d_k, self.d_v
        n_head = self.n_head

        if self.mode == 0:
            qs = self.qs_layer(q)  # [batch_size, len_q, n_head*d_k]
            ks = self.ks_layer(k)
            vs = self.vs_layer(v)

            def reshape1(x):
                s = tf.shape(x)   # [batch_size, len_q, n_head * d_k]
                x = tf.reshape(x, [s[0], s[1], n_head, d_k])
                x = tf.transpose(x, [2, 0, 1, 3])  
                x = tf.reshape(x, [-1, s[1], d_k])  # [n_head * batch_size, len_q, d_k]
                return x
            qs = Lambda(reshape1)(qs)
            ks = Lambda(reshape1)(ks)
            vs = Lambda(reshape1)(vs)

            if mask is not None:
                mask = Lambda(lambda x:K.repeat_elements(x, n_head, 0))(mask)
            head, attn = self.attention(qs, ks, vs, mask=mask)  
                
            def reshape2(x):
                s = tf.shape(x)   # [n_head * batch_size, len_v, d_v]
                x = tf.reshape(x, [n_head, -1, s[1], s[2]]) 
                x = tf.transpose(x, [1, 2, 0, 3])
                x = tf.reshape(x, [-1, s[1], n_head*d_v])  # [batch_size, len_v, n_head * d_v]
                return x
            head = Lambda(reshape2)(head)
        elif self.mode == 1:
            heads = []; attns = []
            for i in range(n_head):
                qs = self.qs_layers[i](q)   
                ks = self.ks_layers[i](k) 
                vs = self.vs_layers[i](v) 
                head, attn = self.attention(qs, ks, vs, mask)
                heads.append(head); attns.append(attn)
            head = Concatenate()(heads) if n_head > 1 else heads[0]
            attn = Concatenate()(attns) if n_head > 1 else attns[0]

        outputs = self.w_o(head)
        outputs = Dropout(self.dropout)(outputs)
        if not self.layer_norm: return outputs, attn
        # outputs = Add()([outputs, q]) # sl: fix
        return self.layer_norm(outputs), attn

class PositionwiseFeedForward():
    def __init__(self, d_hid, d_inner_hid, dropout=0.1):
        self.w_1 = Conv1D(d_inner_hid, 1, activation='relu')
        self.w_2 = Conv1D(d_hid, 1)
        self.layer_norm = LayerNormalization()
        self.dropout = Dropout(dropout)
    def __call__(self, x):
        output = self.w_1(x) 
        output = self.w_2(output)
        output = self.dropout(output)
        output = Add()([output, x])
        return self.layer_norm(output)

class EncoderLayer():
    def __init__(self, d_model, d_inner_hid, n_head, d_k, d_v, dropout=0.1):
        self.self_att_layer = MultiHeadAttention(n_head, d_model, d_k, d_v, dropout=dropout)
        self.pos_ffn_layer  = PositionwiseFeedForward(d_model, d_inner_hid, dropout=dropout)
    def __call__(self, enc_input, mask=None):
        output, slf_attn = self.self_att_layer(enc_input, enc_input, enc_input, mask=mask)
        output = self.pos_ffn_layer(output)
        return output, slf_attn


def GetPosEncodingMatrix(max_len, d_emb):
    pos_enc = np.array([
        [pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)] 
        if pos != 0 else np.zeros(d_emb) 
            for pos in range(max_len)
            ])
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2]) # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2]) # dim 2i+1
    return pos_enc

def GetPadMask(q, k):
    ones = K.expand_dims(K.ones_like(q, 'float32'), -1)
    mask = K.cast(K.expand_dims(K.not_equal(k, 0), 1), 'float32')
    mask = K.batch_dot(ones, mask, axes=[2,1])
    return mask

def GetSubMask(s):
    len_s = tf.shape(s)[1]
    bs = tf.shape(s)[:1]
    mask = K.cumsum(tf.eye(len_s, batch_shape=bs), 1)
    return mask

class Transformer():
    def __init__(self, len_limit, embedding_matrix, d_model=embed_size, \
              d_inner_hid=512, n_head=10, d_k=64, d_v=64, layers=2, dropout=0.1, \
              share_word_emb=False, **kwargs):
        self.name = 'Transformer'
        self.len_limit = len_limit
        self.src_loc_info = False # True # sl: fix later
        self.d_model = d_model
        self.decode_model = None
        d_emb = d_model

        pos_emb = Embedding(len_limit, d_emb, trainable=False, \
                            weights=[GetPosEncodingMatrix(len_limit, d_emb)])

        i_word_emb = Embedding(max_features, d_emb, weights=[embedding_matrix]) # Add Kaggle provided embedding here

        self.encoder = Encoder(d_model, d_inner_hid, n_head, d_k, d_v, layers, dropout, \
                               word_emb=i_word_emb, pos_emb=pos_emb)

        
    def get_pos_seq(self, x):
        mask = K.cast(K.not_equal(x, 0), 'int32')
        pos = K.cumsum(K.ones_like(x, 'int32'), 1)
        return pos * mask

    def compile(self, active_layers=999):
        src_seq_input = Input(shape=(None, ))
        x = Embedding(max_features, embed_size, weights=[embedding_matrix])(src_seq_input)
        
        
        x, slf_attn = MultiHeadAttention(n_head=3, d_model=300, d_k=64, d_v=64, dropout=0.1)(x, x, x)
        
        avg_pool = GlobalAveragePooling1D()(x)
        max_pool = GlobalMaxPooling1D()(x)
        conc = concatenate([avg_pool, max_pool])
        conc = Dense(64, activation="relu")(conc)
        x = Dense(1)(conc)   
        
        
        self.model = Model(inputs=src_seq_input, outputs=x)
        self.model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=['accuracy'])

# %%
def build_model():
    Inp = Input(shape = (SEQ_LEN, 1))
    x = Dense(32, activation="relu")(Inp)
    
    out, slf_attn = MultiHeadAttention(n_head=2, d_model=32, d_k=8, d_v=8, dropout=0.1)(x,x,x)
    out = Dense(32, activation="relu")(out)
    x = x + out
    
    
    out, slf_attn = MultiHeadAttention(n_head=2, d_model=32, d_k=8, d_v=8, dropout=0.1)(x,x,x)
    out = Dense(32, activation="relu")(out)
    x = x + out
    
        
    avg_pool = GlobalAveragePooling1D()(x)
    conc = Dense(64, activation="relu")(avg_pool)
    x = Dense(1)(conc)      

    model = Model(inputs = Inp, outputs = x)
    model.compile(
        loss = "mean_squared_error", 
        #optimizer = Adam(lr = config["lr"], decay = config["lr_d"]), 
        optimizer = Adam(learning_rate=0.0005))
    
    # Save entire model to a HDF5 file
#     model.save('GE_stock_price_model.h5')
    
    return model

# %%
multi_head = build_model()
multi_head.summary()
multi_head.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=30,
                    validation_data=(X_val, y_val), 
                    #callbacks = [checkpoint , lr_reduce]
             )
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.__operators__.add_1), but are not present in its tracked objects:   <tf.Variable 'layer_normalization_2/beta:0' shape=(32,) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.__operators__.add_4), but are not present in its tracked objects:   <tf.Variable 'layer_normalization_3/beta:0' shape=(32,) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 3, 1)]       0           []
#
#  dense_20 (Dense)               (None, 3, 32)        64          ['input_4[0][0]']
#
#  dense_21 (Dense)               (None, 3, 16)        512         ['dense_20[0][0]']
#
#  dense_22 (Dense)               (None, 3, 16)        512         ['dense_20[0][0]']
#
#  lambda_12 (Lambda)             (None, 3, 8)         0           ['dense_21[0][0]']
#
#  lambda_13 (Lambda)             (None, 3, 8)         0           ['dense_22[0][0]']
#
#  lambda_15 (Lambda)             (None, 3, 3)         0           ['lambda_12[0][0]',
#                                                                   'lambda_13[0][0]']
#
#  activation_2 (Activation)      (None, 3, 3)         0           ['lambda_15[0][0]']
#
#  dense_23 (Dense)               (None, 3, 16)        512         ['dense_20[0][0]']
#
#  dropout_7 (Dropout)            (None, 3, 3)         0           ['activation_2[0][0]']
#
#  lambda_14 (Lambda)             (None, 3, 8)         0           ['dense_23[0][0]']
#
#  lambda_16 (Lambda)             (None, 3, 8)         0           ['dropout_7[0][0]',
#                                                                   'lambda_14[0][0]']
#
#  lambda_17 (Lambda)             (None, 3, 16)        0           ['lambda_16[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 3, 32)       544         ['lambda_17[0][0]']
#  buted)
#
#  dropout_8 (Dropout)            (None, 3, 32)        0           ['time_distributed_2[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  (None, 3, 1)        0           ['dropout_8[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLambda)  (None, 3, 32)        0           ['dropout_8[0][0]',
#                                                                   'tf.math.reduce_mean[0][0]']
#
#  tf.math.reduce_std (TFOpLambda  (None, 3, 1)        0           ['dropout_8[0][0]']
#  )
#
#  tf.math.multiply (TFOpLambda)  (None, 3, 32)        0           ['tf.math.subtract[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 3, 1)        0           ['tf.math.reduce_std[0][0]']
#  da)
#
#  tf.math.truediv (TFOpLambda)   (None, 3, 32)        0           ['tf.math.multiply[0][0]',
#                                                                   'tf.__operators__.add[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 3, 32)       0           ['tf.math.truediv[0][0]']
#  mbda)
#
#  dense_25 (Dense)               (None, 3, 32)        1056        ['tf.__operators__.add_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 3, 32)       0           ['dense_20[0][0]',
#  mbda)                                                            'dense_25[0][0]']
#
#  dense_26 (Dense)               (None, 3, 16)        512         ['tf.__operators__.add_2[0][0]']
#
#  dense_27 (Dense)               (None, 3, 16)        512         ['tf.__operators__.add_2[0][0]']
#
#  lambda_18 (Lambda)             (None, 3, 8)         0           ['dense_26[0][0]']
#
#  lambda_19 (Lambda)             (None, 3, 8)         0           ['dense_27[0][0]']
#
#  lambda_21 (Lambda)             (None, 3, 3)         0           ['lambda_18[0][0]',
#                                                                   'lambda_19[0][0]']
#
#  activation_3 (Activation)      (None, 3, 3)         0           ['lambda_21[0][0]']
#
#  dense_28 (Dense)               (None, 3, 16)        512         ['tf.__operators__.add_2[0][0]']
#
#  dropout_9 (Dropout)            (None, 3, 3)         0           ['activation_3[0][0]']
#
#  lambda_20 (Lambda)             (None, 3, 8)         0           ['dense_28[0][0]']
#
#  lambda_22 (Lambda)             (None, 3, 8)         0           ['dropout_9[0][0]',
#                                                                   'lambda_20[0][0]']
#
#  lambda_23 (Lambda)             (None, 3, 16)        0           ['lambda_22[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 3, 32)       544         ['lambda_23[0][0]']
#  buted)
#
#  dropout_10 (Dropout)           (None, 3, 32)        0           ['time_distributed_3[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  (None, 3, 1)        0           ['dropout_10[0][0]']
#  bda)
#
#  tf.math.subtract_1 (TFOpLambda  (None, 3, 32)       0           ['dropout_10[0][0]',
#  )                                                                'tf.math.reduce_mean_1[0][0]']
#
#  tf.math.reduce_std_1 (TFOpLamb  (None, 3, 1)        0           ['dropout_10[0][0]']
#  da)
#
#  tf.math.multiply_1 (TFOpLambda  (None, 3, 32)       0           ['tf.math.subtract_1[0][0]']
#  )
#
#  tf.__operators__.add_3 (TFOpLa  (None, 3, 1)        0           ['tf.math.reduce_std_1[0][0]']
#  mbda)
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 3, 32)       0           ['tf.math.multiply_1[0][0]',
#                                                                   'tf.__operators__.add_3[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 3, 32)       0           ['tf.math.truediv_1[0][0]']
#  mbda)
#
#  dense_30 (Dense)               (None, 3, 32)        1056        ['tf.__operators__.add_4[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 3, 32)       0           ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'dense_30[0][0]']
#
#  global_average_pooling1d (Glob  (None, 32)          0           ['tf.__operators__.add_5[0][0]']
#  alAveragePooling1D)
#
#  dense_31 (Dense)               (None, 64)           2112        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_32 (Dense)               (None, 1)            65          ['dense_31[0][0]']
#
# ==================================================================================================
# Total params: 8,513
# Trainable params: 8,513
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 454/454 [==============================] - 3s 3ms/step - loss: 46.4522 - val_loss: 43.9457
# Epoch 2/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4828 - val_loss: 25.6886
# Epoch 3/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4410 - val_loss: 23.2109
# Epoch 4/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4537 - val_loss: 20.7050
# Epoch 5/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4364 - val_loss: 16.3475
# Epoch 6/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4227 - val_loss: 13.4991
# Epoch 7/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4236 - val_loss: 13.7532
# Epoch 8/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4368 - val_loss: 17.0170
# Epoch 9/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4275 - val_loss: 11.7519
# Epoch 10/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4263 - val_loss: 17.4718
# Epoch 11/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4327 - val_loss: 9.0176
# Epoch 12/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4491 - val_loss: 8.5794
# Epoch 13/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4477 - val_loss: 6.0825
# Epoch 14/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4270 - val_loss: 9.0227
# Epoch 15/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4258 - val_loss: 7.9453
# Epoch 16/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4285 - val_loss: 5.2729
# Epoch 17/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4084 - val_loss: 6.8919
# Epoch 18/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4251 - val_loss: 10.0729
# Epoch 19/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4246 - val_loss: 7.8926
# Epoch 20/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4248 - val_loss: 3.4203
# Epoch 21/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4123 - val_loss: 4.0515
# Epoch 22/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4197 - val_loss: 1.8433
# Epoch 23/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4139 - val_loss: 6.4955
# Epoch 24/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4095 - val_loss: 2.6175
# Epoch 25/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4293 - val_loss: 9.3286
# Epoch 26/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4128 - val_loss: 4.7472
# Epoch 27/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4115 - val_loss: 5.4581
# Epoch 28/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4125 - val_loss: 5.0747
# Epoch 29/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4251 - val_loss: 2.3546
# Epoch 30/30
# 454/454 [==============================] - 1s 2ms/step - loss: 0.4031 - val_loss: 1.8960

# %%
train_predictions = multi_head.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 227/227 [==============================] - 1s 1ms/step

# %%
val_predictions = multi_head.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 29/29 [==============================] - 0s 1ms/step

# %%
test_predictions = multi_head.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 29/29 [==============================] - 0s 1ms/step

# %%
y_pred_test = multi_head.predict(X_test)
mse_test=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# 29/29 [==============================] - 0s 1ms/step
# mse_test: 113.44589

# %%
y_pred_test = multi_head.predict(X_test)
mse_val=mean_squared_error(y_test, y_pred_test)
print('mse_test:',mse_test)
# Out:
# 29/29 [==============================] - 0s 1ms/step
# mse_test: 113.44589
